# %% [markdown]
# # Use the model in a inference behaviour

# %% [markdown]
# 1. Load a cv config with all experiment parameters
# 2. Load the corresponding data,
# 3. create a train and validation generator with the given parameters, exclusive the augmentation parameters
# 4. reconstruct the model with the given parameters, (we have custom loss functions, simple model.load() will not work)
# 5. load and apply the corresponding weights (with respect to the distributed training strategy)
# 6. predict the target vectors with the train and val generators (make sure that we change the batchsize to 1, and avoid shuffle so that we get all files)
# 7. write the gt and predictions as numpy into the corresponding experiment folder

# %%
# ------------------------------------------define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Tensorflow_helper import choose_gpu_by_id
# ------------------------------------------define GPU id/s to use
GPU_IDS = '0,1'
GPUS = choose_gpu_by_id(GPU_IDS)
print(GPUS)
# ------------------------------------------jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# ------------------------------------------ import helpers
# this should import glob, os, and some other standard libs to keep this cell clean
# local imports
from src.utils.Notebook_imports import *
from src.utils.Utils_io import Console_and_file_logger, init_config

# import external libs
from tensorflow.python.client import device_lib
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
import cv2
import pandas as pd
import numpy as np
import SimpleITK as sitk
from ipyfilechooser import FileChooser
from src.data.Generators import DataGenerator
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/wft21_septum_landmark_detection
# ['/gpu:0', '/gpu:1']

# %% [markdown]
# # Load a config into the global namespace

# %%
# Select config of training that you trained on. If Experiment Root was changed change the input-string of the FileChooser aswell.
exp_config_chooser = FileChooser(os.path.join(os.getcwd(),'exp/'), '')
display(exp_config_chooser)
@interact_manual
def load_config():

    global exp_config_chooser, config
    """
    load an experiment config
    """
    if 'exp_config_chooser' in globals():
        config_file  = exp_config_chooser.selected
    else:
        print('no config chooser found')

    # load the experiment config
    with open(config_file, encoding='utf-8') as data_file:
        config = json.loads(data_file.read())
    globals().update(config)
    Console_and_file_logger(EXPERIMENT, logging.INFO)
    logging.info('Loaded config for experiment: {}'.format(config['EXPERIMENT']))
# Out:
# FileChooser(path='/mnt/ssd/git/wft21_septum_landmark_detection/exp', filename='', title='HTML(value='', layout…
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…

# %% [markdown]
# # Load Dataframe based on .csv with fold information.
# ## Manually input desired fold!

# %%
df = pd.read_csv(DF_FOLDS)
# df.head() # shows dataframe with all files and all folds

# Input fold on which you are working. Only the validation data of each fold will be predicted. 
# Load dataframe with all patients of the corresponding fold
df = df[df['fold']==0] 
df.head() 


# useful for troubleshooting , showcases entire dataframe:
# pd.set_option("display.max_rows", None, "display.max_columns", None) 
# print(df)
# Out:
#       Unnamed: 0  fold modality pathology     patient phase  \
# 1200        1200     0    train      MINF  patient050    ED
# 1201        1201     0    train      MINF  patient050    ES
# 1202        1202     0    train       NOR  patient070    ED
# 1203        1203     0    train       NOR  patient070    ES
# 1204        1204     0    train        RV  patient100    ES
#
#                                                  x_path  \
# 1200  data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1201  data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1202  data/raw/ACDC/3D/all/patient070/patient070_fra...
# 1203  data/raw/ACDC/3D/all/patient070/patient070_fra...
# 1204  data/raw/ACDC/3D/all/patient100/patient100_fra...
#
#                                                  y_path
# 1200  data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1201  data/raw/ACDC/3D/all/patient050/patient050_fra...
# 1202  data/raw/ACDC/3D/all/patient070/patient070_fra...
# 1203  data/raw/ACDC/3D/all/patient070/patient070_fra...
# 1204  data/raw/ACDC/3D/all/patient100/patient100_fra...

# %% [markdown]
# # Pandas Dataframe

# %% [markdown]
# # Load the corresponding file names for this fold

# %%
# Load SAX volumes
from src.data.Dataset import get_trainings_files
x_train_sax, y_train_sax, x_val_sax, y_val_sax = get_trainings_files(data_path=DATA_PATH_SAX,
                                                                     path_to_folds_df=DF_FOLDS,
                                                                     fold=FOLD)
logging.info('SAX train CMR: {}, SAX train masks: {}'.format(len(x_train_sax), len(y_train_sax)))
logging.info('SAX val CMR: {}, SAX val masks: {}'.format(len(x_val_sax), len(y_val_sax)))
# Out:
# 2021-10-14 13:23:55,103 INFO Found 1902 images/masks in /mnt/ssd/data/acdc/wft2021/rvip/2D/
# 2021-10-14 13:23:55,103 INFO Patients train: 75
# 2021-10-14 13:23:55,160 INFO Selected 1426 of 1902 files with 75 of 100 patients for training fold 0
# 2021-10-14 13:23:55,160 INFO SAX train CMR: 1426, SAX train masks: 1426
# 2021-10-14 13:23:55,161 INFO SAX val CMR: 476, SAX val masks: 476

# %% [markdown]
# # Load the model, load and set the corresponding weights

# %%
# Load Neural Network based on config.
import src.models.Unets as modelmanager
# create a model
logging.info('Create model')
model = modelmanager.create_unet(config)
model.load_weights(os.path.join(config['MODEL_PATH'],'model.h5'))
logging.info('loaded model weights as h5 file')
model.summary()
# Out:
# 2021-10-14 13:24:11,708 INFO Create model
# using tensorflow, need to monkey patch
# tf.python.backend.slice overwritten by monkey patch
# (None, 128, 128, 1)
# 2021-10-14 13:24:14,225 INFO loaded model weights as h5 file
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_10[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  295040      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_13[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_16[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 18464       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_19[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# unet (Conv2D)                   (None, 128, 128, 2)  66          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 8,641,730
# Trainable params: 8,635,842
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Save gt and pred into experiment folder
# saves groundtruth based on np.stack with gts and predictions as one numpy stack under the pred_filename as a .npy file. The numpy stack is later used to create the images based on the arrays

# %% [markdown]
# # fast hack which aligns the patients

# %%
# get a list of patients for fast testing
patients = [p for p in sorted(df['patient'].unique())]
#patients

# %% [markdown]
# Workaround to align data from generators with dataframe based on .csv.
# The idea is to create one generator per patient.
#
# This means that the original CMR picture and ground-truth are written out in new dimensions aswell, so the predictions can be compared and evaluated using our evaluation script and MITK. This shortcut enables us to skip undoing the generator steps.
#
# Each patient has two 3D-Volumes, corresponding to the end diastolic (ed) and end systolic (es) phase of the cardiac cycle.
# The amount of slices remain the same across volumes of the same patient, allowing us to sort the files and half them to reconstruct the corresponding two 3d-volumes.

# %%
# in short: create one generator per patient
# read config and initialize DataGenerator with given parameters, reading from config. Shuffle and Augmentation have to be off, Batchsize of 1 is required
# logging.getLogger().setLevel(logging.INFO)
from src.data.Generators import DataGenerator
from logging import info
config['SHUFFLE'] = False
config['AUGMENT'] = False
config['AUGMENT_GRID'] = False# make sure no augmentation will be applied to the validation data
config['HIST_MATCHING'] = False
config['BATCHSIZE'] = 1
# by this we can have a different set of parameters for both generators
val_config = config.copy()

# change export_root if needed
export_root = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3'
ensure_dir(export_root)

# only chose data from the test split of each cross-validation-fold
df_fold = df[df['modality']=='test']
#print(df_fold)

# filter a list of filenames by a patient id, this is necessary as the filepath in our df differs from the real filenames
def filter_by_patient_id(p_id, f_names):
    return [elem for elem in f_names if p_id in elem]


# show only data on 'unique' patients to sum up folds and slices
for p in sorted(df_fold['patient'].unique()): # for each patient
    info(p) # shows which patient we are at
    # load files and masks for given patient
    files_ = filter_by_patient_id(p, x_val_sax)
    masks_ = filter_by_patient_id(p, y_val_sax)
    info(len(files_)) # shows amount of slices for each patient
    # collect all files for this patient
    # split in ED and ES, using the fact that both have the same amount of slices and the data is sorted.
    ed_f = files_[:len(files_)//2]
    es_f = files_[len(files_)//2:]
    ed_m = masks_[:len(masks_)//2]
    es_m = masks_[len(masks_)//2:]
    f_ = [ed_f, es_f]
    m_ = [ed_m, es_m]
    phases = ['ED', 'ES']
    assert(len(ed_m)==len(ed_f)), 'number of images and masks should be the same, something went wrong'
    info('length of ed_f ' + str(len(ed_f)))
    info('length of es_f ' + str(len(es_f)))
    #print('this is ed_f ' + ed_f)
    #print('this is es_f ' + es_f)
    
    # the following is looped twice so both phases, ED and ES are processed.
    for p_ in range(2):
        phase_cmr_files = f_[p_] 
        phase_mask_files = m_[p_]
        current_phase = phases[p_]
        info('patient: {}, phase: {}, files: {}'.format(p, current_phase, len(phase_cmr_files)))
        
        # create validation generator just for the given patient and fold. This means that each patient requires two generators. The work around allows us to align the info from the .csv with the data from the generators. 
        validation_generator = DataGenerator(phase_cmr_files, phase_mask_files, config=val_config)

        # get cmr mask and save in a numpy.stack
        gts = np.stack([np.squeeze(y) for x, y in validation_generator])
        logging.info('groundtruth shape' + str(gts.shape))
        #get cmr image and save in a numpy stack
        gts_cmr = np.stack([np.squeeze(x) for x, y in validation_generator])
        logging.info('original cmr shape' + str(gts_cmr.shape))

        # predict on the validation generator
        preds = model.predict(validation_generator)
        logging.info(preds.shape)

        # upper_RVIP = 1, lower_RVIP == 2. Corresponds to annotation guide.
        # transform to int representation (one-hot-encoded)
        # create data based on ground-truth
        gts_flat = np.zeros((gts.shape[:-1]))
        gts_flat[gts[..., 0] > 0.5] = 1
        gts_flat[gts[..., 1] > 0.5] = 2

        # create data based on predictions
        preds_flat = np.zeros((gts.shape[:-1]))
        preds_flat[preds[..., 0] > 0.5] = 1
        preds_flat[preds[..., 1] > 0.5] = 2

        info(gts_flat.shape)
        info(preds_flat.shape)
        info(gts_cmr.shape)

        # Read image data from Array using sitk library
        gt_sitks = sitk.GetImageFromArray(gts_flat.astype(np.uint8))
        pred_sitks = sitk.GetImageFromArray(preds_flat.astype(np.uint8))
        gt_cmr_sitks = sitk.GetImageFromArray(np.stack(gts_cmr, axis=0))

        exp_spacing = tuple(reversed(pred_config.get('SPACING')))
        exp_spacing = (*exp_spacing, 10) # we should use the original spacing in Z. But for the in-plane angle/evaluation it makes no difference
        _ = list(map(lambda x: x.SetSpacing(exp_spacing), [gt_sitks, pred_sitks, gt_cmr_sitks]))

        # Writing images to storage from previously loaded images.
        sitk.WriteImage(gt_sitks, os.path.join(gt_path, '{}_{}_msk.nrrd'.format(p, current_phase)))
        sitk.WriteImage(pred_sitks, os.path.join(pred_path, '{}_{}_msk.nrrd'.format(p, current_phase)))
        sitk.WriteImage(gt_cmr_sitks, os.path.join(pred_path, '{}_{}_cmr.nrrd'.format(p, current_phase)))

logging.info('done! Check the ' + export_root + 'folder for files')
# Out:
# 2021-10-08 14:24:54,402 INFO patient001
# 2021-10-08 14:24:54,403 INFO 20
# 2021-10-08 14:24:54,403 INFO length of ed_f 10
# 2021-10-08 14:24:54,403 INFO length of es_f 10
# 2021-10-08 14:24:54,404 INFO patient: patient001, phase: ED, files: 10
# 2021-10-08 14:24:54,404 INFO Create DataGenerator
# 2021-10-08 14:24:54,405 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:54,405 INFO No augmentation
# 2021-10-08 14:24:54,466 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:54,499 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:56,177 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:56,178 INFO (10, 128, 128)
# 2021-10-08 14:24:56,178 INFO (10, 128, 128)
# 2021-10-08 14:24:56,179 INFO (10, 128, 128)
# 2021-10-08 14:24:56,181 INFO patient: patient001, phase: ES, files: 10
# 2021-10-08 14:24:56,181 INFO Create DataGenerator
# 2021-10-08 14:24:56,182 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:56,182 INFO No augmentation
# 2021-10-08 14:24:56,217 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:56,251 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:56,410 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:56,411 INFO (10, 128, 128)
# 2021-10-08 14:24:56,411 INFO (10, 128, 128)
# 2021-10-08 14:24:56,412 INFO (10, 128, 128)
# 2021-10-08 14:24:56,414 INFO patient002
# 2021-10-08 14:24:56,414 INFO 20
# 2021-10-08 14:24:56,414 INFO length of ed_f 10
# 2021-10-08 14:24:56,415 INFO length of es_f 10
# 2021-10-08 14:24:56,415 INFO patient: patient002, phase: ED, files: 10
# 2021-10-08 14:24:56,415 INFO Create DataGenerator
# 2021-10-08 14:24:56,416 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:56,416 INFO No augmentation
# 2021-10-08 14:24:56,450 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:56,482 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:56,634 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:56,635 INFO (10, 128, 128)
# 2021-10-08 14:24:56,635 INFO (10, 128, 128)
# 2021-10-08 14:24:56,636 INFO (10, 128, 128)
# 2021-10-08 14:24:56,638 INFO patient: patient002, phase: ES, files: 10
# 2021-10-08 14:24:56,638 INFO Create DataGenerator
# 2021-10-08 14:24:56,638 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:56,638 INFO No augmentation
# 2021-10-08 14:24:56,670 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:56,703 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:56,856 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:56,857 INFO (10, 128, 128)
# 2021-10-08 14:24:56,857 INFO (10, 128, 128)
# 2021-10-08 14:24:56,858 INFO (10, 128, 128)
# 2021-10-08 14:24:56,860 INFO patient009
# 2021-10-08 14:24:56,860 INFO 20
# 2021-10-08 14:24:56,860 INFO length of ed_f 10
# 2021-10-08 14:24:56,861 INFO length of es_f 10
# 2021-10-08 14:24:56,861 INFO patient: patient009, phase: ED, files: 10
# 2021-10-08 14:24:56,861 INFO Create DataGenerator
# 2021-10-08 14:24:56,862 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:56,862 INFO No augmentation
# 2021-10-08 14:24:56,896 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:56,929 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:57,080 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:57,081 INFO (10, 128, 128)
# 2021-10-08 14:24:57,081 INFO (10, 128, 128)
# 2021-10-08 14:24:57,081 INFO (10, 128, 128)
# 2021-10-08 14:24:57,084 INFO patient: patient009, phase: ES, files: 10
# 2021-10-08 14:24:57,084 INFO Create DataGenerator
# 2021-10-08 14:24:57,084 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:57,085 INFO No augmentation
# 2021-10-08 14:24:57,116 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:57,147 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:57,306 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:57,307 INFO (10, 128, 128)
# 2021-10-08 14:24:57,307 INFO (10, 128, 128)
# 2021-10-08 14:24:57,308 INFO (10, 128, 128)
# 2021-10-08 14:24:57,309 INFO patient016
# 2021-10-08 14:24:57,310 INFO 20
# 2021-10-08 14:24:57,310 INFO length of ed_f 10
# 2021-10-08 14:24:57,310 INFO length of es_f 10
# 2021-10-08 14:24:57,311 INFO patient: patient016, phase: ED, files: 10
# 2021-10-08 14:24:57,311 INFO Create DataGenerator
# 2021-10-08 14:24:57,312 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:57,312 INFO No augmentation
# 2021-10-08 14:24:57,344 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:57,377 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:57,532 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:57,533 INFO (10, 128, 128)
# 2021-10-08 14:24:57,533 INFO (10, 128, 128)
# 2021-10-08 14:24:57,534 INFO (10, 128, 128)
# 2021-10-08 14:24:57,536 INFO patient: patient016, phase: ES, files: 10
# 2021-10-08 14:24:57,536 INFO Create DataGenerator
# 2021-10-08 14:24:57,537 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:57,537 INFO No augmentation
# 2021-10-08 14:24:57,570 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:57,602 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:57,761 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:57,762 INFO (10, 128, 128)
# 2021-10-08 14:24:57,762 INFO (10, 128, 128)
# 2021-10-08 14:24:57,762 INFO (10, 128, 128)
# 2021-10-08 14:24:57,766 INFO patient018
# 2021-10-08 14:24:57,767 INFO 16
# 2021-10-08 14:24:57,767 INFO length of ed_f 8
# 2021-10-08 14:24:57,767 INFO length of es_f 8
# 2021-10-08 14:24:57,768 INFO patient: patient018, phase: ED, files: 8
# 2021-10-08 14:24:57,768 INFO Create DataGenerator
# 2021-10-08 14:24:57,768 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:57,769 INFO No augmentation
# 2021-10-08 14:24:57,795 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:24:57,822 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:24:57,973 INFO (8, 128, 128, 2)
# 2021-10-08 14:24:57,974 INFO (8, 128, 128)
# 2021-10-08 14:24:57,974 INFO (8, 128, 128)
# 2021-10-08 14:24:57,974 INFO (8, 128, 128)
# 2021-10-08 14:24:57,976 INFO patient: patient018, phase: ES, files: 8
# 2021-10-08 14:24:57,976 INFO Create DataGenerator
# 2021-10-08 14:24:57,977 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:57,977 INFO No augmentation
# 2021-10-08 14:24:58,003 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:24:58,029 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:24:58,179 INFO (8, 128, 128, 2)
# 2021-10-08 14:24:58,180 INFO (8, 128, 128)
# 2021-10-08 14:24:58,180 INFO (8, 128, 128)
# 2021-10-08 14:24:58,181 INFO (8, 128, 128)
# 2021-10-08 14:24:58,182 INFO patient021
# 2021-10-08 14:24:58,183 INFO 20
# 2021-10-08 14:24:58,183 INFO length of ed_f 10
# 2021-10-08 14:24:58,183 INFO length of es_f 10
# 2021-10-08 14:24:58,183 INFO patient: patient021, phase: ED, files: 10
# 2021-10-08 14:24:58,184 INFO Create DataGenerator
# 2021-10-08 14:24:58,184 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:58,185 INFO No augmentation
# 2021-10-08 14:24:58,217 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:58,249 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:58,401 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:58,402 INFO (10, 128, 128)
# 2021-10-08 14:24:58,402 INFO (10, 128, 128)
# 2021-10-08 14:24:58,403 INFO (10, 128, 128)
# 2021-10-08 14:24:58,405 INFO patient: patient021, phase: ES, files: 10
# 2021-10-08 14:24:58,405 INFO Create DataGenerator
# 2021-10-08 14:24:58,405 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:58,406 INFO No augmentation
# 2021-10-08 14:24:58,441 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:24:58,475 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:24:58,641 INFO (10, 128, 128, 2)
# 2021-10-08 14:24:58,642 INFO (10, 128, 128)
# 2021-10-08 14:24:58,643 INFO (10, 128, 128)
# 2021-10-08 14:24:58,643 INFO (10, 128, 128)
# 2021-10-08 14:24:58,645 INFO patient022
# 2021-10-08 14:24:58,645 INFO 14
# 2021-10-08 14:24:58,645 INFO length of ed_f 7
# 2021-10-08 14:24:58,646 INFO length of es_f 7
# 2021-10-08 14:24:58,646 INFO patient: patient022, phase: ED, files: 7
# 2021-10-08 14:24:58,646 INFO Create DataGenerator
# 2021-10-08 14:24:58,647 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:58,647 INFO No augmentation
# 2021-10-08 14:24:58,671 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:24:58,695 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:24:58,836 INFO (7, 128, 128, 2)
# 2021-10-08 14:24:58,837 INFO (7, 128, 128)
# 2021-10-08 14:24:58,837 INFO (7, 128, 128)
# 2021-10-08 14:24:58,838 INFO (7, 128, 128)
# 2021-10-08 14:24:58,839 INFO patient: patient022, phase: ES, files: 7
# 2021-10-08 14:24:58,840 INFO Create DataGenerator
# 2021-10-08 14:24:58,840 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:58,840 INFO No augmentation
# 2021-10-08 14:24:58,864 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:24:58,887 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:24:59,027 INFO (7, 128, 128, 2)
# 2021-10-08 14:24:59,028 INFO (7, 128, 128)
# 2021-10-08 14:24:59,029 INFO (7, 128, 128)
# 2021-10-08 14:24:59,029 INFO (7, 128, 128)
# 2021-10-08 14:24:59,031 INFO patient029
# 2021-10-08 14:24:59,031 INFO 22
# 2021-10-08 14:24:59,031 INFO length of ed_f 11
# 2021-10-08 14:24:59,031 INFO length of es_f 11
# 2021-10-08 14:24:59,032 INFO patient: patient029, phase: ED, files: 11
# 2021-10-08 14:24:59,032 INFO Create DataGenerator
# 2021-10-08 14:24:59,032 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 11
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:59,033 INFO No augmentation
# 2021-10-08 14:24:59,068 INFO groundtruth shape(11, 128, 128, 2)
# 2021-10-08 14:24:59,103 INFO original cmr shape(11, 128, 128)
# 2021-10-08 14:24:59,262 INFO (11, 128, 128, 2)
# 2021-10-08 14:24:59,264 INFO (11, 128, 128)
# 2021-10-08 14:24:59,265 INFO (11, 128, 128)
# 2021-10-08 14:24:59,265 INFO (11, 128, 128)
# 2021-10-08 14:24:59,267 INFO patient: patient029, phase: ES, files: 11
# 2021-10-08 14:24:59,268 INFO Create DataGenerator
# 2021-10-08 14:24:59,268 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 11
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:59,268 INFO No augmentation
# 2021-10-08 14:24:59,306 INFO groundtruth shape(11, 128, 128, 2)
# 2021-10-08 14:24:59,343 INFO original cmr shape(11, 128, 128)
# 2021-10-08 14:24:59,509 INFO (11, 128, 128, 2)
# 2021-10-08 14:24:59,510 INFO (11, 128, 128)
# 2021-10-08 14:24:59,510 INFO (11, 128, 128)
# 2021-10-08 14:24:59,510 INFO (11, 128, 128)
# 2021-10-08 14:24:59,512 INFO patient036
# 2021-10-08 14:24:59,513 INFO 16
# 2021-10-08 14:24:59,513 INFO length of ed_f 8
# 2021-10-08 14:24:59,513 INFO length of es_f 8
# 2021-10-08 14:24:59,513 INFO patient: patient036, phase: ED, files: 8
# 2021-10-08 14:24:59,514 INFO Create DataGenerator
# 2021-10-08 14:24:59,514 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:59,514 INFO No augmentation
# 2021-10-08 14:24:59,541 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:24:59,567 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:24:59,712 INFO (8, 128, 128, 2)
# 2021-10-08 14:24:59,713 INFO (8, 128, 128)
# 2021-10-08 14:24:59,713 INFO (8, 128, 128)
# 2021-10-08 14:24:59,714 INFO (8, 128, 128)
# 2021-10-08 14:24:59,716 INFO patient: patient036, phase: ES, files: 8
# 2021-10-08 14:24:59,716 INFO Create DataGenerator
# 2021-10-08 14:24:59,716 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:59,717 INFO No augmentation
# 2021-10-08 14:24:59,744 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:24:59,773 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:24:59,929 INFO (8, 128, 128, 2)
# 2021-10-08 14:24:59,930 INFO (8, 128, 128)
# 2021-10-08 14:24:59,931 INFO (8, 128, 128)
# 2021-10-08 14:24:59,931 INFO (8, 128, 128)
# 2021-10-08 14:24:59,933 INFO patient038
# 2021-10-08 14:24:59,933 INFO 16
# 2021-10-08 14:24:59,934 INFO length of ed_f 8
# 2021-10-08 14:24:59,934 INFO length of es_f 8
# 2021-10-08 14:24:59,934 INFO patient: patient038, phase: ED, files: 8
# 2021-10-08 14:24:59,934 INFO Create DataGenerator
# 2021-10-08 14:24:59,935 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:24:59,935 INFO No augmentation
# 2021-10-08 14:24:59,961 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:24:59,988 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:00,141 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:00,142 INFO (8, 128, 128)
# 2021-10-08 14:25:00,142 INFO (8, 128, 128)
# 2021-10-08 14:25:00,143 INFO (8, 128, 128)
# 2021-10-08 14:25:00,145 INFO patient: patient038, phase: ES, files: 8
# 2021-10-08 14:25:00,145 INFO Create DataGenerator
# 2021-10-08 14:25:00,145 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:00,146 INFO No augmentation
# 2021-10-08 14:25:00,172 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:25:00,198 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:00,348 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:00,349 INFO (8, 128, 128)
# 2021-10-08 14:25:00,350 INFO (8, 128, 128)
# 2021-10-08 14:25:00,350 INFO (8, 128, 128)
# 2021-10-08 14:25:00,352 INFO patient041
# 2021-10-08 14:25:00,352 INFO 12
# 2021-10-08 14:25:00,352 INFO length of ed_f 6
# 2021-10-08 14:25:00,353 INFO length of es_f 6
# 2021-10-08 14:25:00,353 INFO patient: patient041, phase: ED, files: 6
# 2021-10-08 14:25:00,353 INFO Create DataGenerator
# 2021-10-08 14:25:00,353 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 6
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:00,354 INFO No augmentation
# 2021-10-08 14:25:00,373 INFO groundtruth shape(6, 128, 128, 2)
# 2021-10-08 14:25:00,393 INFO original cmr shape(6, 128, 128)
# 2021-10-08 14:25:00,539 INFO (6, 128, 128, 2)
# 2021-10-08 14:25:00,540 INFO (6, 128, 128)
# 2021-10-08 14:25:00,540 INFO (6, 128, 128)
# 2021-10-08 14:25:00,541 INFO (6, 128, 128)
# 2021-10-08 14:25:00,542 INFO patient: patient041, phase: ES, files: 6
# 2021-10-08 14:25:00,543 INFO Create DataGenerator
# 2021-10-08 14:25:00,543 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 6
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:00,544 INFO No augmentation
# 2021-10-08 14:25:00,565 INFO groundtruth shape(6, 128, 128, 2)
# 2021-10-08 14:25:00,585 INFO original cmr shape(6, 128, 128)
# 2021-10-08 14:25:00,724 INFO (6, 128, 128, 2)
# 2021-10-08 14:25:00,725 INFO (6, 128, 128)
# 2021-10-08 14:25:00,725 INFO (6, 128, 128)
# 2021-10-08 14:25:00,726 INFO (6, 128, 128)
# 2021-10-08 14:25:00,728 INFO patient042
# 2021-10-08 14:25:00,728 INFO 18
# 2021-10-08 14:25:00,728 INFO length of ed_f 9
# 2021-10-08 14:25:00,729 INFO length of es_f 9
# 2021-10-08 14:25:00,729 INFO patient: patient042, phase: ED, files: 9
# 2021-10-08 14:25:00,730 INFO Create DataGenerator
# 2021-10-08 14:25:00,730 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:00,731 INFO No augmentation
# 2021-10-08 14:25:00,762 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:00,794 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:00,943 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:00,944 INFO (9, 128, 128)
# 2021-10-08 14:25:00,944 INFO (9, 128, 128)
# 2021-10-08 14:25:00,944 INFO (9, 128, 128)
# 2021-10-08 14:25:00,946 INFO patient: patient042, phase: ES, files: 9
# 2021-10-08 14:25:00,947 INFO Create DataGenerator
# 2021-10-08 14:25:00,947 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:00,947 INFO No augmentation
# 2021-10-08 14:25:00,979 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:01,010 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:01,171 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:01,172 INFO (9, 128, 128)
# 2021-10-08 14:25:01,173 INFO (9, 128, 128)
# 2021-10-08 14:25:01,173 INFO (9, 128, 128)
# 2021-10-08 14:25:01,175 INFO patient049
# 2021-10-08 14:25:01,175 INFO 14
# 2021-10-08 14:25:01,175 INFO length of ed_f 7
# 2021-10-08 14:25:01,176 INFO length of es_f 7
# 2021-10-08 14:25:01,176 INFO patient: patient049, phase: ED, files: 7
# 2021-10-08 14:25:01,176 INFO Create DataGenerator
# 2021-10-08 14:25:01,177 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:01,177 INFO No augmentation
# 2021-10-08 14:25:01,201 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:01,224 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:01,369 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:01,370 INFO (7, 128, 128)
# 2021-10-08 14:25:01,371 INFO (7, 128, 128)
# 2021-10-08 14:25:01,371 INFO (7, 128, 128)
# 2021-10-08 14:25:01,373 INFO patient: patient049, phase: ES, files: 7
# 2021-10-08 14:25:01,373 INFO Create DataGenerator
# 2021-10-08 14:25:01,374 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:01,374 INFO No augmentation
# 2021-10-08 14:25:01,397 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:01,420 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:01,563 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:01,564 INFO (7, 128, 128)
# 2021-10-08 14:25:01,564 INFO (7, 128, 128)
# 2021-10-08 14:25:01,564 INFO (7, 128, 128)
# 2021-10-08 14:25:01,566 INFO patient056
# 2021-10-08 14:25:01,567 INFO 18
# 2021-10-08 14:25:01,567 INFO length of ed_f 9
# 2021-10-08 14:25:01,567 INFO length of es_f 9
# 2021-10-08 14:25:01,568 INFO patient: patient056, phase: ED, files: 9
# 2021-10-08 14:25:01,568 INFO Create DataGenerator
# 2021-10-08 14:25:01,568 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:01,568 INFO No augmentation
# 2021-10-08 14:25:01,598 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:01,627 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:01,789 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:01,791 INFO (9, 128, 128)
# 2021-10-08 14:25:01,792 INFO (9, 128, 128)
# 2021-10-08 14:25:01,792 INFO (9, 128, 128)
# 2021-10-08 14:25:01,795 INFO patient: patient056, phase: ES, files: 9
# 2021-10-08 14:25:01,795 INFO Create DataGenerator
# 2021-10-08 14:25:01,796 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:01,797 INFO No augmentation
# 2021-10-08 14:25:01,830 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:01,862 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:02,012 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:02,013 INFO (9, 128, 128)
# 2021-10-08 14:25:02,014 INFO (9, 128, 128)
# 2021-10-08 14:25:02,014 INFO (9, 128, 128)
# 2021-10-08 14:25:02,016 INFO patient058
# 2021-10-08 14:25:02,016 INFO 18
# 2021-10-08 14:25:02,017 INFO length of ed_f 9
# 2021-10-08 14:25:02,017 INFO length of es_f 9
# 2021-10-08 14:25:02,017 INFO patient: patient058, phase: ED, files: 9
# 2021-10-08 14:25:02,017 INFO Create DataGenerator
# 2021-10-08 14:25:02,018 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:02,018 INFO No augmentation
# 2021-10-08 14:25:02,048 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:02,077 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:02,229 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:02,231 INFO (9, 128, 128)
# 2021-10-08 14:25:02,231 INFO (9, 128, 128)
# 2021-10-08 14:25:02,232 INFO (9, 128, 128)
# 2021-10-08 14:25:02,234 INFO patient: patient058, phase: ES, files: 9
# 2021-10-08 14:25:02,235 INFO Create DataGenerator
# 2021-10-08 14:25:02,235 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:02,236 INFO No augmentation
# 2021-10-08 14:25:02,266 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:02,296 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:02,449 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:02,450 INFO (9, 128, 128)
# 2021-10-08 14:25:02,451 INFO (9, 128, 128)
# 2021-10-08 14:25:02,451 INFO (9, 128, 128)
# 2021-10-08 14:25:02,453 INFO patient061
# 2021-10-08 14:25:02,454 INFO 18
# 2021-10-08 14:25:02,454 INFO length of ed_f 9
# 2021-10-08 14:25:02,454 INFO length of es_f 9
# 2021-10-08 14:25:02,455 INFO patient: patient061, phase: ED, files: 9
# 2021-10-08 14:25:02,455 INFO Create DataGenerator
# 2021-10-08 14:25:02,455 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:02,456 INFO No augmentation
# 2021-10-08 14:25:02,487 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:02,516 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:02,667 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:02,668 INFO (9, 128, 128)
# 2021-10-08 14:25:02,669 INFO (9, 128, 128)
# 2021-10-08 14:25:02,669 INFO (9, 128, 128)
# 2021-10-08 14:25:02,672 INFO patient: patient061, phase: ES, files: 9
# 2021-10-08 14:25:02,672 INFO Create DataGenerator
# 2021-10-08 14:25:02,672 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:02,673 INFO No augmentation
# 2021-10-08 14:25:02,702 INFO groundtruth shape(9, 128, 128, 2)
# 2021-10-08 14:25:02,731 INFO original cmr shape(9, 128, 128)
# 2021-10-08 14:25:02,878 INFO (9, 128, 128, 2)
# 2021-10-08 14:25:02,880 INFO (9, 128, 128)
# 2021-10-08 14:25:02,880 INFO (9, 128, 128)
# 2021-10-08 14:25:02,880 INFO (9, 128, 128)
# 2021-10-08 14:25:02,883 INFO patient062
# 2021-10-08 14:25:02,883 INFO 20
# 2021-10-08 14:25:02,883 INFO length of ed_f 10
# 2021-10-08 14:25:02,884 INFO length of es_f 10
# 2021-10-08 14:25:02,884 INFO patient: patient062, phase: ED, files: 10
# 2021-10-08 14:25:02,885 INFO Create DataGenerator
# 2021-10-08 14:25:02,885 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:02,885 INFO No augmentation
# 2021-10-08 14:25:02,917 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:25:02,948 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:25:03,102 INFO (10, 128, 128, 2)
# 2021-10-08 14:25:03,103 INFO (10, 128, 128)
# 2021-10-08 14:25:03,103 INFO (10, 128, 128)
# 2021-10-08 14:25:03,103 INFO (10, 128, 128)
# 2021-10-08 14:25:03,106 INFO patient: patient062, phase: ES, files: 10
# 2021-10-08 14:25:03,106 INFO Create DataGenerator
# 2021-10-08 14:25:03,106 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:03,107 INFO No augmentation
# 2021-10-08 14:25:03,141 INFO groundtruth shape(10, 128, 128, 2)
# 2021-10-08 14:25:03,175 INFO original cmr shape(10, 128, 128)
# 2021-10-08 14:25:03,415 INFO (10, 128, 128, 2)
# 2021-10-08 14:25:03,417 INFO (10, 128, 128)
# 2021-10-08 14:25:03,417 INFO (10, 128, 128)
# 2021-10-08 14:25:03,417 INFO (10, 128, 128)
# 2021-10-08 14:25:03,419 INFO patient069
# 2021-10-08 14:25:03,420 INFO 14
# 2021-10-08 14:25:03,420 INFO length of ed_f 7
# 2021-10-08 14:25:03,420 INFO length of es_f 7
# 2021-10-08 14:25:03,421 INFO patient: patient069, phase: ED, files: 7
# 2021-10-08 14:25:03,421 INFO Create DataGenerator
# 2021-10-08 14:25:03,422 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:03,422 INFO No augmentation
# 2021-10-08 14:25:03,446 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:03,468 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:03,610 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:03,612 INFO (7, 128, 128)
# 2021-10-08 14:25:03,612 INFO (7, 128, 128)
# 2021-10-08 14:25:03,612 INFO (7, 128, 128)
# 2021-10-08 14:25:03,614 INFO patient: patient069, phase: ES, files: 7
# 2021-10-08 14:25:03,614 INFO Create DataGenerator
# 2021-10-08 14:25:03,615 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:03,615 INFO No augmentation
# 2021-10-08 14:25:03,639 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:03,662 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:03,809 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:03,810 INFO (7, 128, 128)
# 2021-10-08 14:25:03,810 INFO (7, 128, 128)
# 2021-10-08 14:25:03,810 INFO (7, 128, 128)
# 2021-10-08 14:25:03,812 INFO patient076
# 2021-10-08 14:25:03,813 INFO 16
# 2021-10-08 14:25:03,813 INFO length of ed_f 8
# 2021-10-08 14:25:03,813 INFO length of es_f 8
# 2021-10-08 14:25:03,813 INFO patient: patient076, phase: ED, files: 8
# 2021-10-08 14:25:03,814 INFO Create DataGenerator
# 2021-10-08 14:25:03,814 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:03,814 INFO No augmentation
# 2021-10-08 14:25:03,843 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:25:03,872 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:04,020 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:04,021 INFO (8, 128, 128)
# 2021-10-08 14:25:04,022 INFO (8, 128, 128)
# 2021-10-08 14:25:04,022 INFO (8, 128, 128)
# 2021-10-08 14:25:04,024 INFO patient: patient076, phase: ES, files: 8
# 2021-10-08 14:25:04,024 INFO Create DataGenerator
# 2021-10-08 14:25:04,025 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:04,025 INFO No augmentation
# 2021-10-08 14:25:04,054 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:25:04,084 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:04,237 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:04,238 INFO (8, 128, 128)
# 2021-10-08 14:25:04,238 INFO (8, 128, 128)
# 2021-10-08 14:25:04,238 INFO (8, 128, 128)
# 2021-10-08 14:25:04,241 INFO patient078
# 2021-10-08 14:25:04,242 INFO 16
# 2021-10-08 14:25:04,242 INFO length of ed_f 8
# 2021-10-08 14:25:04,242 INFO length of es_f 8
# 2021-10-08 14:25:04,243 INFO patient: patient078, phase: ED, files: 8
# 2021-10-08 14:25:04,244 INFO Create DataGenerator
# 2021-10-08 14:25:04,244 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:04,244 INFO No augmentation
# 2021-10-08 14:25:04,272 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:25:04,298 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:04,453 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:04,454 INFO (8, 128, 128)
# 2021-10-08 14:25:04,469 INFO (8, 128, 128)
# 2021-10-08 14:25:04,472 INFO (8, 128, 128)
# 2021-10-08 14:25:04,480 INFO patient: patient078, phase: ES, files: 8
# 2021-10-08 14:25:04,481 INFO Create DataGenerator
# 2021-10-08 14:25:04,483 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:04,484 INFO No augmentation
# 2021-10-08 14:25:04,523 INFO groundtruth shape(8, 128, 128, 2)
# 2021-10-08 14:25:04,549 INFO original cmr shape(8, 128, 128)
# 2021-10-08 14:25:04,699 INFO (8, 128, 128, 2)
# 2021-10-08 14:25:04,700 INFO (8, 128, 128)
# 2021-10-08 14:25:04,700 INFO (8, 128, 128)
# 2021-10-08 14:25:04,701 INFO (8, 128, 128)
# 2021-10-08 14:25:04,702 INFO patient081
# 2021-10-08 14:25:04,703 INFO 34
# 2021-10-08 14:25:04,703 INFO length of ed_f 17
# 2021-10-08 14:25:04,703 INFO length of es_f 17
# 2021-10-08 14:25:04,703 INFO patient: patient081, phase: ED, files: 17
# 2021-10-08 14:25:04,704 INFO Create DataGenerator
# 2021-10-08 14:25:04,704 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 17
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:04,704 INFO No augmentation
# 2021-10-08 14:25:04,759 INFO groundtruth shape(17, 128, 128, 2)
# 2021-10-08 14:25:04,816 INFO original cmr shape(17, 128, 128)
# 2021-10-08 14:25:05,008 INFO (17, 128, 128, 2)
# 2021-10-08 14:25:05,010 INFO (17, 128, 128)
# 2021-10-08 14:25:05,010 INFO (17, 128, 128)
# 2021-10-08 14:25:05,011 INFO (17, 128, 128)
# 2021-10-08 14:25:05,014 INFO patient: patient081, phase: ES, files: 17
# 2021-10-08 14:25:05,015 INFO Create DataGenerator
# 2021-10-08 14:25:05,015 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 17
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:05,015 INFO No augmentation
# 2021-10-08 14:25:05,073 INFO groundtruth shape(17, 128, 128, 2)
# 2021-10-08 14:25:05,129 INFO original cmr shape(17, 128, 128)
# 2021-10-08 14:25:05,320 INFO (17, 128, 128, 2)
# 2021-10-08 14:25:05,322 INFO (17, 128, 128)
# 2021-10-08 14:25:05,322 INFO (17, 128, 128)
# 2021-10-08 14:25:05,323 INFO (17, 128, 128)
# 2021-10-08 14:25:05,325 INFO patient082
# 2021-10-08 14:25:05,326 INFO 32
# 2021-10-08 14:25:05,326 INFO length of ed_f 16
# 2021-10-08 14:25:05,326 INFO length of es_f 16
# 2021-10-08 14:25:05,326 INFO patient: patient082, phase: ED, files: 16
# 2021-10-08 14:25:05,327 INFO Create DataGenerator
# 2021-10-08 14:25:05,327 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:05,327 INFO No augmentation
# 2021-10-08 14:25:05,379 INFO groundtruth shape(16, 128, 128, 2)
# 2021-10-08 14:25:05,432 INFO original cmr shape(16, 128, 128)
# 2021-10-08 14:25:05,625 INFO (16, 128, 128, 2)
# 2021-10-08 14:25:05,627 INFO (16, 128, 128)
# 2021-10-08 14:25:05,627 INFO (16, 128, 128)
# 2021-10-08 14:25:05,628 INFO (16, 128, 128)
# 2021-10-08 14:25:05,632 INFO patient: patient082, phase: ES, files: 16
# 2021-10-08 14:25:05,633 INFO Create DataGenerator
# 2021-10-08 14:25:05,633 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:05,634 INFO No augmentation
# 2021-10-08 14:25:05,687 INFO groundtruth shape(16, 128, 128, 2)
# 2021-10-08 14:25:05,740 INFO original cmr shape(16, 128, 128)
# 2021-10-08 14:25:05,925 INFO (16, 128, 128, 2)
# 2021-10-08 14:25:05,926 INFO (16, 128, 128)
# 2021-10-08 14:25:05,927 INFO (16, 128, 128)
# 2021-10-08 14:25:05,927 INFO (16, 128, 128)
# 2021-10-08 14:25:05,930 INFO patient089
# 2021-10-08 14:25:05,930 INFO 12
# 2021-10-08 14:25:05,930 INFO length of ed_f 6
# 2021-10-08 14:25:05,931 INFO length of es_f 6
# 2021-10-08 14:25:05,931 INFO patient: patient089, phase: ED, files: 6
# 2021-10-08 14:25:05,931 INFO Create DataGenerator
# 2021-10-08 14:25:05,932 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 6
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:05,932 INFO No augmentation
# 2021-10-08 14:25:05,954 INFO groundtruth shape(6, 128, 128, 2)
# 2021-10-08 14:25:05,975 INFO original cmr shape(6, 128, 128)
# 2021-10-08 14:25:06,123 INFO (6, 128, 128, 2)
# 2021-10-08 14:25:06,124 INFO (6, 128, 128)
# 2021-10-08 14:25:06,124 INFO (6, 128, 128)
# 2021-10-08 14:25:06,125 INFO (6, 128, 128)
# 2021-10-08 14:25:06,126 INFO patient: patient089, phase: ES, files: 6
# 2021-10-08 14:25:06,127 INFO Create DataGenerator
# 2021-10-08 14:25:06,127 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 6
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:06,127 INFO No augmentation
# 2021-10-08 14:25:06,149 INFO groundtruth shape(6, 128, 128, 2)
# 2021-10-08 14:25:06,170 INFO original cmr shape(6, 128, 128)
# 2021-10-08 14:25:06,320 INFO (6, 128, 128, 2)
# 2021-10-08 14:25:06,321 INFO (6, 128, 128)
# 2021-10-08 14:25:06,322 INFO (6, 128, 128)
# 2021-10-08 14:25:06,322 INFO (6, 128, 128)
# 2021-10-08 14:25:06,324 INFO patient096
# 2021-10-08 14:25:06,324 INFO 36
# 2021-10-08 14:25:06,325 INFO length of ed_f 18
# 2021-10-08 14:25:06,325 INFO length of es_f 18
# 2021-10-08 14:25:06,326 INFO patient: patient096, phase: ED, files: 18
# 2021-10-08 14:25:06,326 INFO Create DataGenerator
# 2021-10-08 14:25:06,327 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 18
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:06,327 INFO No augmentation
# 2021-10-08 14:25:06,386 INFO groundtruth shape(18, 128, 128, 2)
# 2021-10-08 14:25:06,443 INFO original cmr shape(18, 128, 128)
# 2021-10-08 14:25:06,635 INFO (18, 128, 128, 2)
# 2021-10-08 14:25:06,637 INFO (18, 128, 128)
# 2021-10-08 14:25:06,638 INFO (18, 128, 128)
# 2021-10-08 14:25:06,638 INFO (18, 128, 128)
# 2021-10-08 14:25:06,641 INFO patient: patient096, phase: ES, files: 18
# 2021-10-08 14:25:06,641 INFO Create DataGenerator
# 2021-10-08 14:25:06,641 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 18
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:06,642 INFO No augmentation
# 2021-10-08 14:25:06,700 INFO groundtruth shape(18, 128, 128, 2)
# 2021-10-08 14:25:06,759 INFO original cmr shape(18, 128, 128)
# 2021-10-08 14:25:06,953 INFO (18, 128, 128, 2)
# 2021-10-08 14:25:06,955 INFO (18, 128, 128)
# 2021-10-08 14:25:06,955 INFO (18, 128, 128)
# 2021-10-08 14:25:06,955 INFO (18, 128, 128)
# 2021-10-08 14:25:06,958 INFO patient098
# 2021-10-08 14:25:06,958 INFO 14
# 2021-10-08 14:25:06,959 INFO length of ed_f 7
# 2021-10-08 14:25:06,959 INFO length of es_f 7
# 2021-10-08 14:25:06,959 INFO patient: patient098, phase: ED, files: 7
# 2021-10-08 14:25:06,959 INFO Create DataGenerator
# 2021-10-08 14:25:06,960 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:06,960 INFO No augmentation
# 2021-10-08 14:25:06,984 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:07,006 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:07,155 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:07,156 INFO (7, 128, 128)
# 2021-10-08 14:25:07,156 INFO (7, 128, 128)
# 2021-10-08 14:25:07,157 INFO (7, 128, 128)
# 2021-10-08 14:25:07,159 INFO patient: patient098, phase: ES, files: 7
# 2021-10-08 14:25:07,159 INFO Create DataGenerator
# 2021-10-08 14:25:07,159 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-10-08 14:25:07,159 INFO No augmentation
# 2021-10-08 14:25:07,183 INFO groundtruth shape(7, 128, 128, 2)
# 2021-10-08 14:25:07,205 INFO original cmr shape(7, 128, 128)
# 2021-10-08 14:25:07,357 INFO (7, 128, 128, 2)
# 2021-10-08 14:25:07,358 INFO (7, 128, 128)
# 2021-10-08 14:25:07,358 INFO (7, 128, 128)
# 2021-10-08 14:25:07,359 INFO (7, 128, 128)
# 2021-10-08 14:25:07,361 INFO done! Check the /mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3folder for files

# %% [markdown]
# # Undo the generator steps
#
# - if you want to plot the predictions onto the original CMR images, you need to reverse the generator steps. This is currently not implemented nor needed.
#
# - If we have masks, undo the cropping/padding, resampling etc. so that our masks have the same size/spacing and name as our input volumes
# - If we have regression coordinates, make sure that they could be applied on the input volumes
