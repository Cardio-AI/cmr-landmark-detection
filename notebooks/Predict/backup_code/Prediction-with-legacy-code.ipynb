# %% [markdown]
# # Use the model in a inference behaviour

# %% [markdown]
# 1. Load a cv config with all experiment parameters
# 2. Load the corresponding data,
# 3. create a train and validation generator with the given parameters, exclusive the augmentation parameters
# 4. reconstruct the model with the given parameters, (we have custom loss functions, simple model.load() will not work)
# 5. load and apply the corresponding weights (with respect to the distributed training strategy)
# 6. predict the target vectors with the train and val generators (make sure that we change the batchsize to 1, and avoid shuffle so that we get all files)
# 7. write the gt and predictions as numpy into the corresponding experiment folder

# %%
# ------------------------------------------define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Tensorflow_helper import choose_gpu_by_id
# ------------------------------------------define GPU id/s to use
GPU_IDS = '0,1'
GPUS = choose_gpu_by_id(GPU_IDS)
print(GPUS)
# ------------------------------------------jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# ------------------------------------------ import helpers
# this should import glob, os, and some other standard libs to keep this cell clean
# local imports
from src.utils.Notebook_imports import *
from src.utils.Utils_io import Console_and_file_logger, init_config

# import external libs
from tensorflow.python.client import device_lib
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
import cv2
import pandas as pd
import numpy as np
import SimpleITK as sitk
from ipyfilechooser import FileChooser
from src.data.Generators import DataGenerator
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/wft21_septum_landmark_detection
# ['/gpu:0', '/gpu:1']

# %% [markdown]
# # Load a config into the global namespace

# %%
# Select config of training that you trained on. If Experiment Root was changed change the input-string of the FileChooser aswell.
exp_config_chooser = FileChooser(os.path.join(os.getcwd(),'exp/'), '')
display(exp_config_chooser)
@interact_manual
def load_config():

    global exp_config_chooser, config
    """
    load an experiment config
    """
    if 'exp_config_chooser' in globals():
        config_file  = exp_config_chooser.selected
    else:
        print('no config chooser found')

    # load the experiment config
    with open(config_file, encoding='utf-8') as data_file:
        config = json.loads(data_file.read())
    globals().update(config)
    Console_and_file_logger(EXPERIMENT, logging.INFO)
    logging.info('Loaded config for experiment: {}'.format(config['EXPERIMENT']))
# Out:
# FileChooser(path='/mnt/ssd/git/wft21_septum_landmark_detection/exp', filename='', title='HTML(value='', layout…
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…

# %%
df = pd.read_csv(DF_FOLDS)
df.head() # shows dataframe with all files


# # useful for troubleshooting , showcases entire dataframe
# pd.set_option("display.max_rows", None, "display.max_columns", None) 
# print(df)
# Out:
#    fold modality pathology     patient  \
# 0     3    train        RV  patient082
# 1     3    train        RV  patient082
# 2     3    train        RV  patient082
# 3     3    train        RV  patient082
# 4     3    train        RV  patient082
#
#                                               x_path  \
# 0  data/raw/ACDC/2D/train/patient082__t01_z0_img....
# 1  data/raw/ACDC/2D/train/patient082__t01_z10_img...
# 2  data/raw/ACDC/2D/train/patient082__t01_z11_img...
# 3  data/raw/ACDC/2D/train/patient082__t01_z12_img...
# 4  data/raw/ACDC/2D/train/patient082__t01_z13_img...
#
#                                               y_path
# 0  data/raw/ACDC/2D/train/patient082__t01_z0_msk....
# 1  data/raw/ACDC/2D/train/patient082__t01_z10_msk...
# 2  data/raw/ACDC/2D/train/patient082__t01_z11_msk...
# 3  data/raw/ACDC/2D/train/patient082__t01_z12_msk...
# 4  data/raw/ACDC/2D/train/patient082__t01_z13_msk...

# %%
# Input fold on which you are working. Only the validation data of each fold will be predicted. 
# Load dataframe with all patients of the corresponding fold
df = df[df['fold']==3] 
df.head()
# Out:
#    fold modality pathology     patient  \
# 0     3    train        RV  patient082
# 1     3    train        RV  patient082
# 2     3    train        RV  patient082
# 3     3    train        RV  patient082
# 4     3    train        RV  patient082
#
#                                               x_path  \
# 0  data/raw/ACDC/2D/train/patient082__t01_z0_img....
# 1  data/raw/ACDC/2D/train/patient082__t01_z10_img...
# 2  data/raw/ACDC/2D/train/patient082__t01_z11_img...
# 3  data/raw/ACDC/2D/train/patient082__t01_z12_img...
# 4  data/raw/ACDC/2D/train/patient082__t01_z13_img...
#
#                                               y_path
# 0  data/raw/ACDC/2D/train/patient082__t01_z0_msk....
# 1  data/raw/ACDC/2D/train/patient082__t01_z10_msk...
# 2  data/raw/ACDC/2D/train/patient082__t01_z11_msk...
# 3  data/raw/ACDC/2D/train/patient082__t01_z12_msk...
# 4  data/raw/ACDC/2D/train/patient082__t01_z13_msk...

# %%
#for p in df['patient'].unique(): # show only data on 'unique' patients to sum up folds and slices
for p in sorted(df['patient'].unique()):
    print(p)
    files_ = df[df['patient'] ==p]['x_path'].values
    print(len(files_)) # shows amount of slices for each patient
    #print(files_[0]) # files is a list with the name of all patient data
    ed_f = files_[:len(files_)//2]
    es_f = files_[len(files_)//2:]
    print('length of ed_f ' + str(len(ed_f)))
    print('length of es_f ' + str(len(es_f)))
# Out:
# patient001
# 20
# length of ed_f 10
# length of es_f 10
# patient002
# 20
# length of ed_f 10
# length of es_f 10
# patient003
# 20
# length of ed_f 10
# length of es_f 10
# patient004
# 20
# length of ed_f 10
# length of es_f 10
# patient005
# 20
# length of ed_f 10
# length of es_f 10
# patient006
# 22
# length of ed_f 11
# length of es_f 11
# patient007
# 20
# length of ed_f 10
# length of es_f 10
# patient008
# 20
# length of ed_f 10
# length of es_f 10
# patient009
# 20
# length of ed_f 10
# length of es_f 10
# patient010
# 20
# length of ed_f 10
# length of es_f 10
# patient011
# 18
# length of ed_f 9
# length of es_f 9
# patient012
# 20
# length of ed_f 10
# length of es_f 10
# patient013
# 20
# length of ed_f 10
# length of es_f 10
# patient014
# 20
# length of ed_f 10
# length of es_f 10
# patient015
# 18
# length of ed_f 9
# length of es_f 9
# patient016
# 20
# length of ed_f 10
# length of es_f 10
# patient017
# 18
# length of ed_f 9
# length of es_f 9
# patient018
# 16
# length of ed_f 8
# length of es_f 8
# patient019
# 22
# length of ed_f 11
# length of es_f 11
# patient020
# 16
# length of ed_f 8
# length of es_f 8
# patient021
# 20
# length of ed_f 10
# length of es_f 10
# patient022
# 14
# length of ed_f 7
# length of es_f 7
# patient023
# 18
# length of ed_f 9
# length of es_f 9
# patient024
# 16
# length of ed_f 8
# length of es_f 8
# patient025
# 18
# length of ed_f 9
# length of es_f 9
# patient026
# 20
# length of ed_f 10
# length of es_f 10
# patient027
# 20
# length of ed_f 10
# length of es_f 10
# patient028
# 20
# length of ed_f 10
# length of es_f 10
# patient029
# 22
# length of ed_f 11
# length of es_f 11
# patient030
# 20
# length of ed_f 10
# length of es_f 10
# patient031
# 20
# length of ed_f 10
# length of es_f 10
# patient032
# 20
# length of ed_f 10
# length of es_f 10
# patient033
# 20
# length of ed_f 10
# length of es_f 10
# patient034
# 20
# length of ed_f 10
# length of es_f 10
# patient035
# 26
# length of ed_f 13
# length of es_f 13
# patient036
# 16
# length of ed_f 8
# length of es_f 8
# patient037
# 14
# length of ed_f 7
# length of es_f 7
# patient038
# 16
# length of ed_f 8
# length of es_f 8
# patient039
# 18
# length of ed_f 9
# length of es_f 9
# patient040
# 20
# length of ed_f 10
# length of es_f 10
# patient041
# 12
# length of ed_f 6
# length of es_f 6
# patient042
# 18
# length of ed_f 9
# length of es_f 9
# patient043
# 24
# length of ed_f 12
# length of es_f 12
# patient044
# 18
# length of ed_f 9
# length of es_f 9
# patient045
# 16
# length of ed_f 8
# length of es_f 8
# patient046
# 18
# length of ed_f 9
# length of es_f 9
# patient047
# 18
# length of ed_f 9
# length of es_f 9
# patient048
# 16
# length of ed_f 8
# length of es_f 8
# patient049
# 14
# length of ed_f 7
# length of es_f 7
# patient050
# 20
# length of ed_f 10
# length of es_f 10
# patient051
# 20
# length of ed_f 10
# length of es_f 10
# patient052
# 16
# length of ed_f 8
# length of es_f 8
# patient053
# 14
# length of ed_f 7
# length of es_f 7
# patient054
# 16
# length of ed_f 8
# length of es_f 8
# patient055
# 18
# length of ed_f 9
# length of es_f 9
# patient056
# 18
# length of ed_f 9
# length of es_f 9
# patient057
# 16
# length of ed_f 8
# length of es_f 8
# patient058
# 18
# length of ed_f 9
# length of es_f 9
# patient059
# 18
# length of ed_f 9
# length of es_f 9
# patient060
# 18
# length of ed_f 9
# length of es_f 9
# patient061
# 18
# length of ed_f 9
# length of es_f 9
# patient062
# 20
# length of ed_f 10
# length of es_f 10
# patient063
# 16
# length of ed_f 8
# length of es_f 8
# patient064
# 20
# length of ed_f 10
# length of es_f 10
# patient065
# 16
# length of ed_f 8
# length of es_f 8
# patient066
# 18
# length of ed_f 9
# length of es_f 9
# patient067
# 20
# length of ed_f 10
# length of es_f 10
# patient068
# 14
# length of ed_f 7
# length of es_f 7
# patient069
# 14
# length of ed_f 7
# length of es_f 7
# patient070
# 12
# length of ed_f 6
# length of es_f 6
# patient071
# 20
# length of ed_f 10
# length of es_f 10
# patient072
# 16
# length of ed_f 8
# length of es_f 8
# patient073
# 14
# length of ed_f 7
# length of es_f 7
# patient074
# 16
# length of ed_f 8
# length of es_f 8
# patient075
# 28
# length of ed_f 14
# length of es_f 14
# patient076
# 16
# length of ed_f 8
# length of es_f 8
# patient077
# 16
# length of ed_f 8
# length of es_f 8
# patient078
# 16
# length of ed_f 8
# length of es_f 8
# patient079
# 18
# length of ed_f 9
# length of es_f 9
# patient080
# 12
# length of ed_f 6
# length of es_f 6
# patient081
# 34
# length of ed_f 17
# length of es_f 17
# patient082
# 32
# length of ed_f 16
# length of es_f 16
# patient083
# 12
# length of ed_f 6
# length of es_f 6
# patient084
# 24
# length of ed_f 12
# length of es_f 12
# patient085
# 30
# length of ed_f 15
# length of es_f 15
# patient086
# 14
# length of ed_f 7
# length of es_f 7
# patient087
# 16
# length of ed_f 8
# length of es_f 8
# patient088
# 32
# length of ed_f 16
# length of es_f 16
# patient089
# 12
# length of ed_f 6
# length of es_f 6
# patient090
# 14
# length of ed_f 7
# length of es_f 7
# patient091
# 16
# length of ed_f 8
# length of es_f 8
# patient092
# 30
# length of ed_f 15
# length of es_f 15
# patient093
# 20
# length of ed_f 10
# length of es_f 10
# patient094
# 20
# length of ed_f 10
# length of es_f 10
# patient095
# 28
# length of ed_f 14
# length of es_f 14
# patient096
# 36
# length of ed_f 18
# length of es_f 18
# patient097
# 16
# length of ed_f 8
# length of es_f 8
# patient098
# 14
# length of ed_f 7
# length of es_f 7
# patient099
# 32
# length of ed_f 16
# length of es_f 16
# patient100
# 16
# length of ed_f 8
# length of es_f 8

# %% [raw]
# Each patient has two 3D-Volumes, corresponding to the end diastolic (ed) and end systolic (es) phase of the cardiac cycle.
# The amount of slices remain the same across volumes of the same patient, allowing us to sort the files and half them to reconstruct the corresponding two 3d-volumes.

# %% [markdown]
# # Pandas Dataframe

# %% [markdown]
# # Load the corresponding file names for this fold

# %%
# Load SAX volumes
from src.data.Dataset import get_trainings_files
x_train_sax, y_train_sax, x_val_sax, y_val_sax = get_trainings_files(data_path=DATA_PATH_SAX,
                                                                     path_to_folds_df=DF_FOLDS,
                                                                     fold=FOLD)
logging.info('SAX train CMR: {}, SAX train masks: {}'.format(len(x_train_sax), len(y_train_sax)))
logging.info('SAX val CMR: {}, SAX val masks: {}'.format(len(x_val_sax), len(y_val_sax)))
# Out:
# 2021-07-11 13:13:15,440 INFO Found 1902 images/masks in /mnt/ssd/data/WFT_MRT21/Export_2021-05-26_16_03
# 2021-07-11 13:13:15,441 INFO Patients train: 75
# 2021-07-11 13:13:15,498 INFO Selected 1452 of 1902 files with 75 of 100 patients for training fold 2
# 2021-07-11 13:13:15,499 INFO SAX train CMR: 1452, SAX train masks: 1452
# 2021-07-11 13:13:15,499 INFO SAX val CMR: 450, SAX val masks: 450

# %% [markdown]
# # Create the same the train and val generators as used for the training of this model
#
# Make sure that:
# - no shuffle
# - no augmentation (classic and temporal)
# - batchsize equal 1

# %%
# Load DataGenerator based on config and configure correctly. 

from src.data.Generators import DataGenerator
config['SHUFFLE'] = False
config['AUGMENT'] = False
config['AUGMENT_GRID'] = False# make sure no augmentation will be applied to the validation data
config['HIST_MATCHING'] = False
config['BATCHSIZE'] = 1
batch_generator = DataGenerator(x_train_sax, y_train_sax, config=config)
# create another config for the validation data, 
# by this we can have a different set of parameters for both generators
val_config = config.copy()
validation_generator = DataGenerator(x_val_sax, y_val_sax, config=val_config) 
# Debugging: Check x_val_sax for troubleshooting
# logging.info(x_val_sax)
# Out:
# 2021-07-11 13:13:19,201 INFO Create DataGenerator
# 2021-07-11 13:13:19,209 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 1452
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:13:19,210 INFO No augmentation
# 2021-07-11 13:13:19,210 INFO Create DataGenerator
# 2021-07-11 13:13:19,212 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 450
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:13:19,213 INFO No augmentation

# %% [markdown]
# # Load the model, load and set the corresponding weights

# %%
# Load Neural Network based on config.
import src.models.Unets as modelmanager
# create a model
logging.info('Create model')
model = modelmanager.create_unet(config)
model.load_weights(os.path.join(config['MODEL_PATH'],'model.h5'))
logging.info('loaded model weights as h5 file')
model.summary()
# Out:
# 2021-07-11 13:13:20,286 INFO Create model
# using tensorflow, need to monkey patch
# tf.python.backend.slice overwritten by monkey patch
# (None, 128, 128, 1)
# 2021-07-11 13:13:21,873 INFO loaded model weights as h5 file
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_10[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  295040      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_13[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_16[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 18464       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_19[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# unet (Conv2D)                   (None, 128, 128, 2)  66          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 8,641,730
# Trainable params: 8,635,842
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Predict on the validation split

# %%
# predict on the validation generator to only predict validation data of each fold
preds = model.predict(validation_generator)

# shape should be number of validation files, x-dim, y-dim, 2
logging.info(preds.shape)
# Out:
# 2021-07-11 13:13:26,924 INFO (450, 128, 128, 2)

# %% [markdown]
# # Create one numpy object from

# %%
# get all ground truth vectors and create a numpy stack
gts = np.stack([np.squeeze(y) for x, y in validation_generator])
logging.info(gts.shape)
# Out:
# 2021-07-06 16:21:23,284 INFO (476, 128, 128, 2)

# %%
# get all original cmr images and add to numpy stack
gts_cmr = np.stack([np.squeeze(x) for x, y in validation_generator])
logging.info(gts_cmr.shape)
# Out:
# 2021-07-06 16:21:24,766 INFO (476, 128, 128)

# %% [raw]
# Q: Unsure what the different np.squeeze functions do. Docs say it removes axes of lenght = 1. But why do we call in once on x and once on y? What exactly are we calling it on?

# %% [markdown]
# # Save gt and pred into experiment folder
# saves groundtruth based on np.stack with gts and predictions as one numpy stack under the pred_filename as a .npy file. The numpy stack is later used to create the images based on the arrays

# %%
#checks_out
pred_path = os.path.join(config['EXP_PATH'], 'predictions_'+ str(datetime.datetime.now().strftime("%Y-%m-%d_%H_%M")))
ensure_dir(pred_path)
pred_filename = os.path.join(pred_path, 'gtpred_fold{}.npy'.format(config['FOLD'])) #names file according to fold, in our case only fold0
np.save(pred_filename, np.stack([gts, preds], axis=0)) 
logging.info('saved as: \n{} \ndone!'.format(pred_filename))
# Out:
# 2021-07-06 16:21:26,122 INFO saved as:
# exp/temp/TeaMRT_Exp1/2021-07-06_13_48/predictions_2021-07-06_16_21/gtpred_fold0.npy
# done!

# %% [raw]
# the predictions are loaded as an array stack. array stack 0 corresponds to the groundtruths , array stack 1 to the predictions

# %%
#checks_out

#np.load('/mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename))

stack = np.load('/mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename)) # loads current predictions from folder
print('the shape of the numpy.stack is' + str(np.shape(stack)))
print(('loading from: /mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename)))

#for-loop over stack --> reading numpy and transferring with pynrrd. pad_and_crop function applied. saving with the name of original file.
# Out:
# the shape of the numpy.stack is(2, 476, 128, 128, 2)
# loading from: /mnt/ssd/git/wft21_septum_landmark_detection/exp/temp/TeaMRT_Exp1/2021-07-06_13_48/predictions_2021-07-06_16_21/gtpred_fold0.npy

# %% [raw]
# this is where the loops need to come in I think. It reads through all the data, and creates a numpy stack from it. Sorting of data can be seen here aswell.

# %% [markdown]
# # fast hack which aligns the patients

# %%
# get a list of patients for fast testing
patients = [p for p in sorted(df['patient'].unique())]
#patients

# %%
# in short: create one generator per patient
# this is a fast hack, it is not very fast
# DataGenerator for SAX, changed from PhaseRegression Generator
# logging.getLogger().setLevel(logging.INFO)
from src.data.Generators import DataGenerator
from logging import info
config['SHUFFLE'] = False
config['AUGMENT'] = False
config['AUGMENT_GRID'] = False# make sure no augmentation will be applied to the validation data
config['HIST_MATCHING'] = False
config['BATCHSIZE'] = 1
# by this we can have a different set of parameters for both generators
val_config = config.copy()
export_root = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3'
ensure_dir(export_root)

df_fold = df[df['modality']=='test']
#print(df_fold)

# filter a list of filenames by a patient id, this is necessary as the filepath in our df differs from the real filenames
def filter_by_patient_id(p_id, f_names):
    return [elem for elem in f_names if p_id in elem]


#for p in df['patient'].unique(): # show only data on 'unique' patients to sum up folds and slices
for p in sorted(df_fold['patient'].unique()): # for each patient
    info(p) # shows which patient we are at
    files_ = filter_by_patient_id(p, x_val_sax)
    masks_ = filter_by_patient_id(p, y_val_sax)
    info(len(files_)) # shows amount of slices for each patient
    #print(files_[0]) # files is a list with the name of all patient data
    # collect all files for this patient
    # split in ED and ES
    ed_f = files_[:len(files_)//2]
    es_f = files_[len(files_)//2:]
    ed_m = masks_[:len(masks_)//2]
    es_m = masks_[len(masks_)//2:]
    f_ = [ed_f, es_f]
    m_ = [ed_m, es_m]
    phases = ['ED', 'ES']
    assert(len(ed_m)==len(ed_f)), 'number of images and masks should be the same, something went wrong'
    info('length of ed_f ' + str(len(ed_f)))
    info('length of es_f ' + str(len(es_f)))
    #print('this is ed_f ' + ed_f)
    #print('this is es_f ' + es_f)
    for p_ in range(2):
        phase_cmr_files = f_[p_] 
        phase_mask_files = m_[p_]
        current_phase = phases[p_]
        info('patient: {}, phase: {}, files: {}'.format(p, current_phase, len(phase_cmr_files)))
        
        validation_generator = DataGenerator(phase_cmr_files, phase_mask_files, config=val_config)

        # get cmr mask
        gts = np.stack([np.squeeze(y) for x, y in validation_generator])
        logging.info('groundtruth shape' + str(gts.shape))
        #get cmr image
        gts_cmr = np.stack([np.squeeze(x) for x, y in validation_generator])
        logging.info('original cmr shape' + str(gts_cmr.shape))

        # predict on the validation generator
        preds = model.predict(validation_generator)
        logging.info(preds.shape)

        # upper = 1, lower == 2
        # transform to int representation (one-hot)
        gts_flat = np.zeros((gts.shape[:-1]))
        gts_flat[gts[...,0]>0.5] = 1
        gts_flat[gts[...,1]>0.5] = 2

        preds_flat = np.zeros((gts.shape[:-1]))
        preds_flat[preds[...,0]>0.5] = 1
        preds_flat[preds[...,1]>0.5] = 2
        
        info(gts_flat.shape)
        info(preds_flat.shape)
        info(gts_cmr.shape)
        #print(preds_flat) #NotIncluded
        gt_sitks = sitk.GetImageFromArray(gts_flat.astype(np.uint8))
        pred_sitks = sitk.GetImageFromArray(preds_flat.astype(np.uint8))
        gt_cmr_sitks = sitk.GetImageFromArray(np.stack(gts_cmr, axis = 0))
        
        #sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_cmr[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_new_temp_cmr.nrrd')
        
        # please write here the pred_sitk and gt_sitk and gt_cmr_sitk to disk
        sitk.WriteImage(gt_sitks, os.path.join(export_root, '{}_{}_gt.nrrd'.format(p, current_phase)))
        sitk.WriteImage(pred_sitks, os.path.join(export_root, '{}_{}_pred.nrrd'.format(p, current_phase)))
        sitk.WriteImage(gt_cmr_sitks, os.path.join(export_root, '{}_{}_cmr.nrrd'.format(p, current_phase)))
        #sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_cmr[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_new_temp_cmr.nrrd')

logging.info('done! Check the ' + export_root + 'folder for files')
# Out:
# 2021-07-11 13:11:02,877 INFO patient007
# 2021-07-11 13:11:02,878 INFO 20
# 2021-07-11 13:11:02,878 INFO length of ed_f 10
# 2021-07-11 13:11:02,879 INFO length of es_f 10
# 2021-07-11 13:11:02,879 INFO patient: patient007, phase: ED, files: 10
# 2021-07-11 13:11:02,880 INFO Create DataGenerator
# 2021-07-11 13:11:02,880 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:02,881 INFO No augmentation
# 2021-07-11 13:11:02,919 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:02,963 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:03,146 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:03,148 INFO (10, 128, 128)
# 2021-07-11 13:11:03,148 INFO (10, 128, 128)
# 2021-07-11 13:11:03,148 INFO (10, 128, 128)
# 2021-07-11 13:11:03,151 INFO patient: patient007, phase: ES, files: 10
# 2021-07-11 13:11:03,151 INFO Create DataGenerator
# 2021-07-11 13:11:03,151 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:03,151 INFO No augmentation
# 2021-07-11 13:11:03,185 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:03,219 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:03,366 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:03,368 INFO (10, 128, 128)
# 2021-07-11 13:11:03,368 INFO (10, 128, 128)
# 2021-07-11 13:11:03,368 INFO (10, 128, 128)
# 2021-07-11 13:11:03,370 INFO patient008
# 2021-07-11 13:11:03,371 INFO 20
# 2021-07-11 13:11:03,371 INFO length of ed_f 10
# 2021-07-11 13:11:03,371 INFO length of es_f 10
# 2021-07-11 13:11:03,372 INFO patient: patient008, phase: ED, files: 10
# 2021-07-11 13:11:03,372 INFO Create DataGenerator
# 2021-07-11 13:11:03,372 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:03,372 INFO No augmentation
# 2021-07-11 13:11:03,406 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:03,439 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:03,586 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:03,587 INFO (10, 128, 128)
# 2021-07-11 13:11:03,588 INFO (10, 128, 128)
# 2021-07-11 13:11:03,588 INFO (10, 128, 128)
# 2021-07-11 13:11:03,590 INFO patient: patient008, phase: ES, files: 10
# 2021-07-11 13:11:03,591 INFO Create DataGenerator
# 2021-07-11 13:11:03,591 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:03,592 INFO No augmentation
# 2021-07-11 13:11:03,625 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:03,657 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:03,807 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:03,809 INFO (10, 128, 128)
# 2021-07-11 13:11:03,809 INFO (10, 128, 128)
# 2021-07-11 13:11:03,810 INFO (10, 128, 128)
# 2021-07-11 13:11:03,812 INFO patient011
# 2021-07-11 13:11:03,813 INFO 18
# 2021-07-11 13:11:03,813 INFO length of ed_f 9
# 2021-07-11 13:11:03,813 INFO length of es_f 9
# 2021-07-11 13:11:03,814 INFO patient: patient011, phase: ED, files: 9
# 2021-07-11 13:11:03,814 INFO Create DataGenerator
# 2021-07-11 13:11:03,815 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:03,815 INFO No augmentation
# 2021-07-11 13:11:03,845 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:03,874 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:04,017 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:04,018 INFO (9, 128, 128)
# 2021-07-11 13:11:04,018 INFO (9, 128, 128)
# 2021-07-11 13:11:04,018 INFO (9, 128, 128)
# 2021-07-11 13:11:04,020 INFO patient: patient011, phase: ES, files: 9
# 2021-07-11 13:11:04,021 INFO Create DataGenerator
# 2021-07-11 13:11:04,021 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:04,021 INFO No augmentation
# 2021-07-11 13:11:04,051 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:04,081 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:04,235 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:04,236 INFO (9, 128, 128)
# 2021-07-11 13:11:04,236 INFO (9, 128, 128)
# 2021-07-11 13:11:04,237 INFO (9, 128, 128)
# 2021-07-11 13:11:04,239 INFO patient013
# 2021-07-11 13:11:04,239 INFO 20
# 2021-07-11 13:11:04,239 INFO length of ed_f 10
# 2021-07-11 13:11:04,240 INFO length of es_f 10
# 2021-07-11 13:11:04,240 INFO patient: patient013, phase: ED, files: 10
# 2021-07-11 13:11:04,240 INFO Create DataGenerator
# 2021-07-11 13:11:04,240 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:04,241 INFO No augmentation
# 2021-07-11 13:11:04,274 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:04,308 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:04,461 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:04,463 INFO (10, 128, 128)
# 2021-07-11 13:11:04,463 INFO (10, 128, 128)
# 2021-07-11 13:11:04,463 INFO (10, 128, 128)
# 2021-07-11 13:11:04,466 INFO patient: patient013, phase: ES, files: 10
# 2021-07-11 13:11:04,466 INFO Create DataGenerator
# 2021-07-11 13:11:04,467 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:04,467 INFO No augmentation
# 2021-07-11 13:11:04,501 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:04,535 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:04,685 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:04,686 INFO (10, 128, 128)
# 2021-07-11 13:11:04,687 INFO (10, 128, 128)
# 2021-07-11 13:11:04,687 INFO (10, 128, 128)
# 2021-07-11 13:11:04,689 INFO patient015
# 2021-07-11 13:11:04,690 INFO 18
# 2021-07-11 13:11:04,690 INFO length of ed_f 9
# 2021-07-11 13:11:04,690 INFO length of es_f 9
# 2021-07-11 13:11:04,691 INFO patient: patient015, phase: ED, files: 9
# 2021-07-11 13:11:04,691 INFO Create DataGenerator
# 2021-07-11 13:11:04,691 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:04,691 INFO No augmentation
# 2021-07-11 13:11:04,722 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:04,751 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:04,901 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:04,903 INFO (9, 128, 128)
# 2021-07-11 13:11:04,903 INFO (9, 128, 128)
# 2021-07-11 13:11:04,903 INFO (9, 128, 128)
# 2021-07-11 13:11:04,905 INFO patient: patient015, phase: ES, files: 9
# 2021-07-11 13:11:04,906 INFO Create DataGenerator
# 2021-07-11 13:11:04,906 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:04,906 INFO No augmentation
# 2021-07-11 13:11:04,938 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:04,968 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:05,120 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:05,121 INFO (9, 128, 128)
# 2021-07-11 13:11:05,121 INFO (9, 128, 128)
# 2021-07-11 13:11:05,122 INFO (9, 128, 128)
# 2021-07-11 13:11:05,124 INFO patient027
# 2021-07-11 13:11:05,124 INFO 20
# 2021-07-11 13:11:05,124 INFO length of ed_f 10
# 2021-07-11 13:11:05,124 INFO length of es_f 10
# 2021-07-11 13:11:05,125 INFO patient: patient027, phase: ED, files: 10
# 2021-07-11 13:11:05,125 INFO Create DataGenerator
# 2021-07-11 13:11:05,125 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:05,125 INFO No augmentation
# 2021-07-11 13:11:05,158 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:05,190 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:05,341 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:05,342 INFO (10, 128, 128)
# 2021-07-11 13:11:05,343 INFO (10, 128, 128)
# 2021-07-11 13:11:05,343 INFO (10, 128, 128)
# 2021-07-11 13:11:05,345 INFO patient: patient027, phase: ES, files: 10
# 2021-07-11 13:11:05,345 INFO Create DataGenerator
# 2021-07-11 13:11:05,346 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:05,346 INFO No augmentation
# 2021-07-11 13:11:05,379 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:05,412 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:05,566 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:05,567 INFO (10, 128, 128)
# 2021-07-11 13:11:05,567 INFO (10, 128, 128)
# 2021-07-11 13:11:05,568 INFO (10, 128, 128)
# 2021-07-11 13:11:05,570 INFO patient028
# 2021-07-11 13:11:05,570 INFO 20
# 2021-07-11 13:11:05,571 INFO length of ed_f 10
# 2021-07-11 13:11:05,571 INFO length of es_f 10
# 2021-07-11 13:11:05,571 INFO patient: patient028, phase: ED, files: 10
# 2021-07-11 13:11:05,571 INFO Create DataGenerator
# 2021-07-11 13:11:05,572 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:05,572 INFO No augmentation
# 2021-07-11 13:11:05,607 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:05,643 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:05,799 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:05,801 INFO (10, 128, 128)
# 2021-07-11 13:11:05,801 INFO (10, 128, 128)
# 2021-07-11 13:11:05,801 INFO (10, 128, 128)
# 2021-07-11 13:11:05,804 INFO patient: patient028, phase: ES, files: 10
# 2021-07-11 13:11:05,804 INFO Create DataGenerator
# 2021-07-11 13:11:05,804 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:05,805 INFO No augmentation
# 2021-07-11 13:11:05,839 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:05,874 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:06,026 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:06,027 INFO (10, 128, 128)
# 2021-07-11 13:11:06,027 INFO (10, 128, 128)
# 2021-07-11 13:11:06,028 INFO (10, 128, 128)
# 2021-07-11 13:11:06,030 INFO patient031
# 2021-07-11 13:11:06,030 INFO 20
# 2021-07-11 13:11:06,031 INFO length of ed_f 10
# 2021-07-11 13:11:06,031 INFO length of es_f 10
# 2021-07-11 13:11:06,032 INFO patient: patient031, phase: ED, files: 10
# 2021-07-11 13:11:06,032 INFO Create DataGenerator
# 2021-07-11 13:11:06,033 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:06,033 INFO No augmentation
# 2021-07-11 13:11:06,067 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:06,100 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:06,244 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:06,245 INFO (10, 128, 128)
# 2021-07-11 13:11:06,245 INFO (10, 128, 128)
# 2021-07-11 13:11:06,246 INFO (10, 128, 128)
# 2021-07-11 13:11:06,248 INFO patient: patient031, phase: ES, files: 10
# 2021-07-11 13:11:06,248 INFO Create DataGenerator
# 2021-07-11 13:11:06,248 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:06,248 INFO No augmentation
# 2021-07-11 13:11:06,282 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:06,317 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:06,477 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:06,479 INFO (10, 128, 128)
# 2021-07-11 13:11:06,479 INFO (10, 128, 128)
# 2021-07-11 13:11:06,479 INFO (10, 128, 128)
# 2021-07-11 13:11:06,482 INFO patient033
# 2021-07-11 13:11:06,482 INFO 20
# 2021-07-11 13:11:06,483 INFO length of ed_f 10
# 2021-07-11 13:11:06,483 INFO length of es_f 10
# 2021-07-11 13:11:06,483 INFO patient: patient033, phase: ED, files: 10
# 2021-07-11 13:11:06,483 INFO Create DataGenerator
# 2021-07-11 13:11:06,484 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:06,484 INFO No augmentation
# 2021-07-11 13:11:06,519 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:06,552 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:06,705 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:06,707 INFO (10, 128, 128)
# 2021-07-11 13:11:06,707 INFO (10, 128, 128)
# 2021-07-11 13:11:06,708 INFO (10, 128, 128)
# 2021-07-11 13:11:06,710 INFO patient: patient033, phase: ES, files: 10
# 2021-07-11 13:11:06,710 INFO Create DataGenerator
# 2021-07-11 13:11:06,711 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:06,711 INFO No augmentation
# 2021-07-11 13:11:06,746 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:06,779 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:06,922 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:06,923 INFO (10, 128, 128)
# 2021-07-11 13:11:06,924 INFO (10, 128, 128)
# 2021-07-11 13:11:06,925 INFO (10, 128, 128)
# 2021-07-11 13:11:06,927 INFO patient035
# 2021-07-11 13:11:06,927 INFO 26
# 2021-07-11 13:11:06,927 INFO length of ed_f 13
# 2021-07-11 13:11:06,928 INFO length of es_f 13
# 2021-07-11 13:11:06,929 INFO patient: patient035, phase: ED, files: 13
# 2021-07-11 13:11:06,929 INFO Create DataGenerator
# 2021-07-11 13:11:06,930 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 13
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:06,931 INFO No augmentation
# 2021-07-11 13:11:06,978 INFO groundtruth shape(13, 128, 128, 2)
# 2021-07-11 13:11:07,023 INFO original cmr shape(13, 128, 128)
# 2021-07-11 13:11:07,186 INFO (13, 128, 128, 2)
# 2021-07-11 13:11:07,187 INFO (13, 128, 128)
# 2021-07-11 13:11:07,188 INFO (13, 128, 128)
# 2021-07-11 13:11:07,188 INFO (13, 128, 128)
# 2021-07-11 13:11:07,190 INFO patient: patient035, phase: ES, files: 13
# 2021-07-11 13:11:07,191 INFO Create DataGenerator
# 2021-07-11 13:11:07,191 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 13
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:07,191 INFO No augmentation
# 2021-07-11 13:11:07,235 INFO groundtruth shape(13, 128, 128, 2)
# 2021-07-11 13:11:07,277 INFO original cmr shape(13, 128, 128)
# 2021-07-11 13:11:07,438 INFO (13, 128, 128, 2)
# 2021-07-11 13:11:07,440 INFO (13, 128, 128)
# 2021-07-11 13:11:07,440 INFO (13, 128, 128)
# 2021-07-11 13:11:07,441 INFO (13, 128, 128)
# 2021-07-11 13:11:07,443 INFO patient047
# 2021-07-11 13:11:07,444 INFO 18
# 2021-07-11 13:11:07,444 INFO length of ed_f 9
# 2021-07-11 13:11:07,445 INFO length of es_f 9
# 2021-07-11 13:11:07,445 INFO patient: patient047, phase: ED, files: 9
# 2021-07-11 13:11:07,445 INFO Create DataGenerator
# 2021-07-11 13:11:07,446 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:07,446 INFO No augmentation
# 2021-07-11 13:11:07,478 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:07,510 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:07,663 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:07,665 INFO (9, 128, 128)
# 2021-07-11 13:11:07,665 INFO (9, 128, 128)
# 2021-07-11 13:11:07,665 INFO (9, 128, 128)
# 2021-07-11 13:11:07,667 INFO patient: patient047, phase: ES, files: 9
# 2021-07-11 13:11:07,668 INFO Create DataGenerator
# 2021-07-11 13:11:07,668 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:07,668 INFO No augmentation
# 2021-07-11 13:11:07,700 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:07,730 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:07,874 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:07,876 INFO (9, 128, 128)
# 2021-07-11 13:11:07,882 INFO (9, 128, 128)
# 2021-07-11 13:11:07,882 INFO (9, 128, 128)
# 2021-07-11 13:11:07,884 INFO patient048
# 2021-07-11 13:11:07,884 INFO 16
# 2021-07-11 13:11:07,885 INFO length of ed_f 8
# 2021-07-11 13:11:07,885 INFO length of es_f 8
# 2021-07-11 13:11:07,885 INFO patient: patient048, phase: ED, files: 8
# 2021-07-11 13:11:07,886 INFO Create DataGenerator
# 2021-07-11 13:11:07,886 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:07,886 INFO No augmentation
# 2021-07-11 13:11:07,914 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:07,942 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:08,084 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:08,085 INFO (8, 128, 128)
# 2021-07-11 13:11:08,085 INFO (8, 128, 128)
# 2021-07-11 13:11:08,086 INFO (8, 128, 128)
# 2021-07-11 13:11:08,088 INFO patient: patient048, phase: ES, files: 8
# 2021-07-11 13:11:08,088 INFO Create DataGenerator
# 2021-07-11 13:11:08,088 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:08,089 INFO No augmentation
# 2021-07-11 13:11:08,116 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:08,143 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:08,290 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:08,291 INFO (8, 128, 128)
# 2021-07-11 13:11:08,291 INFO (8, 128, 128)
# 2021-07-11 13:11:08,292 INFO (8, 128, 128)
# 2021-07-11 13:11:08,293 INFO patient051
# 2021-07-11 13:11:08,294 INFO 20
# 2021-07-11 13:11:08,294 INFO length of ed_f 10
# 2021-07-11 13:11:08,294 INFO length of es_f 10
# 2021-07-11 13:11:08,295 INFO patient: patient051, phase: ED, files: 10
# 2021-07-11 13:11:08,295 INFO Create DataGenerator
# 2021-07-11 13:11:08,295 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:08,296 INFO No augmentation
# 2021-07-11 13:11:08,329 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:08,362 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:08,509 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:08,511 INFO (10, 128, 128)
# 2021-07-11 13:11:08,511 INFO (10, 128, 128)
# 2021-07-11 13:11:08,511 INFO (10, 128, 128)
# 2021-07-11 13:11:08,513 INFO patient: patient051, phase: ES, files: 10
# 2021-07-11 13:11:08,514 INFO Create DataGenerator
# 2021-07-11 13:11:08,514 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:08,514 INFO No augmentation
# 2021-07-11 13:11:08,550 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:08,585 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:08,732 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:08,733 INFO (10, 128, 128)
# 2021-07-11 13:11:08,733 INFO (10, 128, 128)
# 2021-07-11 13:11:08,734 INFO (10, 128, 128)
# 2021-07-11 13:11:08,736 INFO patient053
# 2021-07-11 13:11:08,736 INFO 14
# 2021-07-11 13:11:08,736 INFO length of ed_f 7
# 2021-07-11 13:11:08,736 INFO length of es_f 7
# 2021-07-11 13:11:08,737 INFO patient: patient053, phase: ED, files: 7
# 2021-07-11 13:11:08,737 INFO Create DataGenerator
# 2021-07-11 13:11:08,738 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:08,738 INFO No augmentation
# 2021-07-11 13:11:08,760 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:08,782 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:08,913 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:08,915 INFO (7, 128, 128)
# 2021-07-11 13:11:08,915 INFO (7, 128, 128)
# 2021-07-11 13:11:08,915 INFO (7, 128, 128)
# 2021-07-11 13:11:08,917 INFO patient: patient053, phase: ES, files: 7
# 2021-07-11 13:11:08,917 INFO Create DataGenerator
# 2021-07-11 13:11:08,918 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:08,918 INFO No augmentation
# 2021-07-11 13:11:08,946 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:08,970 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:09,105 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:09,106 INFO (7, 128, 128)
# 2021-07-11 13:11:09,107 INFO (7, 128, 128)
# 2021-07-11 13:11:09,107 INFO (7, 128, 128)
# 2021-07-11 13:11:09,109 INFO patient055
# 2021-07-11 13:11:09,110 INFO 18
# 2021-07-11 13:11:09,110 INFO length of ed_f 9
# 2021-07-11 13:11:09,111 INFO length of es_f 9
# 2021-07-11 13:11:09,111 INFO patient: patient055, phase: ED, files: 9
# 2021-07-11 13:11:09,111 INFO Create DataGenerator
# 2021-07-11 13:11:09,112 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:09,112 INFO No augmentation
# 2021-07-11 13:11:09,142 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:09,172 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:09,320 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:09,322 INFO (9, 128, 128)
# 2021-07-11 13:11:09,322 INFO (9, 128, 128)
# 2021-07-11 13:11:09,322 INFO (9, 128, 128)
# 2021-07-11 13:11:09,324 INFO patient: patient055, phase: ES, files: 9
# 2021-07-11 13:11:09,325 INFO Create DataGenerator
# 2021-07-11 13:11:09,325 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:09,325 INFO No augmentation
# 2021-07-11 13:11:09,356 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 13:11:09,385 INFO original cmr shape(9, 128, 128)
# 2021-07-11 13:11:09,528 INFO (9, 128, 128, 2)
# 2021-07-11 13:11:09,529 INFO (9, 128, 128)
# 2021-07-11 13:11:09,530 INFO (9, 128, 128)
# 2021-07-11 13:11:09,530 INFO (9, 128, 128)
# 2021-07-11 13:11:09,532 INFO patient067
# 2021-07-11 13:11:09,532 INFO 20
# 2021-07-11 13:11:09,533 INFO length of ed_f 10
# 2021-07-11 13:11:09,533 INFO length of es_f 10
# 2021-07-11 13:11:09,533 INFO patient: patient067, phase: ED, files: 10
# 2021-07-11 13:11:09,534 INFO Create DataGenerator
# 2021-07-11 13:11:09,534 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:09,534 INFO No augmentation
# 2021-07-11 13:11:09,566 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:09,598 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:09,742 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:09,744 INFO (10, 128, 128)
# 2021-07-11 13:11:09,744 INFO (10, 128, 128)
# 2021-07-11 13:11:09,744 INFO (10, 128, 128)
# 2021-07-11 13:11:09,746 INFO patient: patient067, phase: ES, files: 10
# 2021-07-11 13:11:09,747 INFO Create DataGenerator
# 2021-07-11 13:11:09,747 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:09,747 INFO No augmentation
# 2021-07-11 13:11:09,780 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:09,812 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:09,955 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:09,957 INFO (10, 128, 128)
# 2021-07-11 13:11:09,957 INFO (10, 128, 128)
# 2021-07-11 13:11:09,957 INFO (10, 128, 128)
# 2021-07-11 13:11:09,960 INFO patient068
# 2021-07-11 13:11:09,960 INFO 14
# 2021-07-11 13:11:09,961 INFO length of ed_f 7
# 2021-07-11 13:11:09,961 INFO length of es_f 7
# 2021-07-11 13:11:09,962 INFO patient: patient068, phase: ED, files: 7
# 2021-07-11 13:11:09,962 INFO Create DataGenerator
# 2021-07-11 13:11:09,962 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:09,963 INFO No augmentation
# 2021-07-11 13:11:09,987 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:10,010 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:10,233 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:10,234 INFO (7, 128, 128)
# 2021-07-11 13:11:10,234 INFO (7, 128, 128)
# 2021-07-11 13:11:10,235 INFO (7, 128, 128)
# 2021-07-11 13:11:10,236 INFO patient: patient068, phase: ES, files: 7
# 2021-07-11 13:11:10,237 INFO Create DataGenerator
# 2021-07-11 13:11:10,237 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:10,237 INFO No augmentation
# 2021-07-11 13:11:10,261 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:10,284 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:10,419 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:10,420 INFO (7, 128, 128)
# 2021-07-11 13:11:10,421 INFO (7, 128, 128)
# 2021-07-11 13:11:10,421 INFO (7, 128, 128)
# 2021-07-11 13:11:10,423 INFO patient071
# 2021-07-11 13:11:10,423 INFO 20
# 2021-07-11 13:11:10,424 INFO length of ed_f 10
# 2021-07-11 13:11:10,424 INFO length of es_f 10
# 2021-07-11 13:11:10,424 INFO patient: patient071, phase: ED, files: 10
# 2021-07-11 13:11:10,424 INFO Create DataGenerator
# 2021-07-11 13:11:10,425 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:10,425 INFO No augmentation
# 2021-07-11 13:11:10,458 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:10,490 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:10,639 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:10,641 INFO (10, 128, 128)
# 2021-07-11 13:11:10,641 INFO (10, 128, 128)
# 2021-07-11 13:11:10,642 INFO (10, 128, 128)
# 2021-07-11 13:11:10,644 INFO patient: patient071, phase: ES, files: 10
# 2021-07-11 13:11:10,645 INFO Create DataGenerator
# 2021-07-11 13:11:10,645 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:10,645 INFO No augmentation
# 2021-07-11 13:11:10,677 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:10,709 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:10,856 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:10,857 INFO (10, 128, 128)
# 2021-07-11 13:11:10,857 INFO (10, 128, 128)
# 2021-07-11 13:11:10,858 INFO (10, 128, 128)
# 2021-07-11 13:11:10,860 INFO patient073
# 2021-07-11 13:11:10,860 INFO 14
# 2021-07-11 13:11:10,860 INFO length of ed_f 7
# 2021-07-11 13:11:10,861 INFO length of es_f 7
# 2021-07-11 13:11:10,861 INFO patient: patient073, phase: ED, files: 7
# 2021-07-11 13:11:10,861 INFO Create DataGenerator
# 2021-07-11 13:11:10,861 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:10,862 INFO No augmentation
# 2021-07-11 13:11:10,886 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:10,909 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:11,069 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:11,071 INFO (7, 128, 128)
# 2021-07-11 13:11:11,071 INFO (7, 128, 128)
# 2021-07-11 13:11:11,071 INFO (7, 128, 128)
# 2021-07-11 13:11:11,074 INFO patient: patient073, phase: ES, files: 7
# 2021-07-11 13:11:11,074 INFO Create DataGenerator
# 2021-07-11 13:11:11,074 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:11,075 INFO No augmentation
# 2021-07-11 13:11:11,099 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 13:11:11,122 INFO original cmr shape(7, 128, 128)
# 2021-07-11 13:11:11,261 INFO (7, 128, 128, 2)
# 2021-07-11 13:11:11,262 INFO (7, 128, 128)
# 2021-07-11 13:11:11,262 INFO (7, 128, 128)
# 2021-07-11 13:11:11,263 INFO (7, 128, 128)
# 2021-07-11 13:11:11,265 INFO patient075
# 2021-07-11 13:11:11,265 INFO 28
# 2021-07-11 13:11:11,265 INFO length of ed_f 14
# 2021-07-11 13:11:11,266 INFO length of es_f 14
# 2021-07-11 13:11:11,266 INFO patient: patient075, phase: ED, files: 14
# 2021-07-11 13:11:11,266 INFO Create DataGenerator
# 2021-07-11 13:11:11,266 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:11,267 INFO No augmentation
# 2021-07-11 13:11:11,312 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 13:11:11,358 INFO original cmr shape(14, 128, 128)
# 2021-07-11 13:11:11,519 INFO (14, 128, 128, 2)
# 2021-07-11 13:11:11,521 INFO (14, 128, 128)
# 2021-07-11 13:11:11,522 INFO (14, 128, 128)
# 2021-07-11 13:11:11,522 INFO (14, 128, 128)
# 2021-07-11 13:11:11,525 INFO patient: patient075, phase: ES, files: 14
# 2021-07-11 13:11:11,525 INFO Create DataGenerator
# 2021-07-11 13:11:11,525 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:11,526 INFO No augmentation
# 2021-07-11 13:11:11,572 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 13:11:11,618 INFO original cmr shape(14, 128, 128)
# 2021-07-11 13:11:11,781 INFO (14, 128, 128, 2)
# 2021-07-11 13:11:11,783 INFO (14, 128, 128)
# 2021-07-11 13:11:11,783 INFO (14, 128, 128)
# 2021-07-11 13:11:11,783 INFO (14, 128, 128)
# 2021-07-11 13:11:11,786 INFO patient087
# 2021-07-11 13:11:11,787 INFO 16
# 2021-07-11 13:11:11,787 INFO length of ed_f 8
# 2021-07-11 13:11:11,788 INFO length of es_f 8
# 2021-07-11 13:11:11,788 INFO patient: patient087, phase: ED, files: 8
# 2021-07-11 13:11:11,788 INFO Create DataGenerator
# 2021-07-11 13:11:11,789 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:11,789 INFO No augmentation
# 2021-07-11 13:11:11,817 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:11,842 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:11,985 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:11,986 INFO (8, 128, 128)
# 2021-07-11 13:11:11,986 INFO (8, 128, 128)
# 2021-07-11 13:11:11,987 INFO (8, 128, 128)
# 2021-07-11 13:11:11,988 INFO patient: patient087, phase: ES, files: 8
# 2021-07-11 13:11:11,989 INFO Create DataGenerator
# 2021-07-11 13:11:11,989 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:11,989 INFO No augmentation
# 2021-07-11 13:11:12,015 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:12,041 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:12,189 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:12,190 INFO (8, 128, 128)
# 2021-07-11 13:11:12,190 INFO (8, 128, 128)
# 2021-07-11 13:11:12,191 INFO (8, 128, 128)
# 2021-07-11 13:11:12,193 INFO patient088
# 2021-07-11 13:11:12,193 INFO 32
# 2021-07-11 13:11:12,193 INFO length of ed_f 16
# 2021-07-11 13:11:12,194 INFO length of es_f 16
# 2021-07-11 13:11:12,194 INFO patient: patient088, phase: ED, files: 16
# 2021-07-11 13:11:12,194 INFO Create DataGenerator
# 2021-07-11 13:11:12,194 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:12,195 INFO No augmentation
# 2021-07-11 13:11:12,250 INFO groundtruth shape(16, 128, 128, 2)
# 2021-07-11 13:11:12,304 INFO original cmr shape(16, 128, 128)
# 2021-07-11 13:11:12,477 INFO (16, 128, 128, 2)
# 2021-07-11 13:11:12,479 INFO (16, 128, 128)
# 2021-07-11 13:11:12,480 INFO (16, 128, 128)
# 2021-07-11 13:11:12,480 INFO (16, 128, 128)
# 2021-07-11 13:11:12,483 INFO patient: patient088, phase: ES, files: 16
# 2021-07-11 13:11:12,483 INFO Create DataGenerator
# 2021-07-11 13:11:12,483 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:12,484 INFO No augmentation
# 2021-07-11 13:11:12,535 INFO groundtruth shape(16, 128, 128, 2)
# 2021-07-11 13:11:12,587 INFO original cmr shape(16, 128, 128)
# 2021-07-11 13:11:12,753 INFO (16, 128, 128, 2)
# 2021-07-11 13:11:12,755 INFO (16, 128, 128)
# 2021-07-11 13:11:12,755 INFO (16, 128, 128)
# 2021-07-11 13:11:12,755 INFO (16, 128, 128)
# 2021-07-11 13:11:12,758 INFO patient091
# 2021-07-11 13:11:12,759 INFO 16
# 2021-07-11 13:11:12,759 INFO length of ed_f 8
# 2021-07-11 13:11:12,759 INFO length of es_f 8
# 2021-07-11 13:11:12,760 INFO patient: patient091, phase: ED, files: 8
# 2021-07-11 13:11:12,761 INFO Create DataGenerator
# 2021-07-11 13:11:12,761 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:12,762 INFO No augmentation
# 2021-07-11 13:11:12,787 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:12,813 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:12,962 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:12,963 INFO (8, 128, 128)
# 2021-07-11 13:11:12,963 INFO (8, 128, 128)
# 2021-07-11 13:11:12,964 INFO (8, 128, 128)
# 2021-07-11 13:11:12,966 INFO patient: patient091, phase: ES, files: 8
# 2021-07-11 13:11:12,966 INFO Create DataGenerator
# 2021-07-11 13:11:12,966 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:12,967 INFO No augmentation
# 2021-07-11 13:11:12,993 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 13:11:13,018 INFO original cmr shape(8, 128, 128)
# 2021-07-11 13:11:13,155 INFO (8, 128, 128, 2)
# 2021-07-11 13:11:13,156 INFO (8, 128, 128)
# 2021-07-11 13:11:13,157 INFO (8, 128, 128)
# 2021-07-11 13:11:13,157 INFO (8, 128, 128)
# 2021-07-11 13:11:13,159 INFO patient093
# 2021-07-11 13:11:13,159 INFO 20
# 2021-07-11 13:11:13,160 INFO length of ed_f 10
# 2021-07-11 13:11:13,160 INFO length of es_f 10
# 2021-07-11 13:11:13,160 INFO patient: patient093, phase: ED, files: 10
# 2021-07-11 13:11:13,160 INFO Create DataGenerator
# 2021-07-11 13:11:13,161 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:13,161 INFO No augmentation
# 2021-07-11 13:11:13,193 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:13,224 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:13,374 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:13,375 INFO (10, 128, 128)
# 2021-07-11 13:11:13,376 INFO (10, 128, 128)
# 2021-07-11 13:11:13,376 INFO (10, 128, 128)
# 2021-07-11 13:11:13,378 INFO patient: patient093, phase: ES, files: 10
# 2021-07-11 13:11:13,378 INFO Create DataGenerator
# 2021-07-11 13:11:13,378 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:13,379 INFO No augmentation
# 2021-07-11 13:11:13,410 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 13:11:13,441 INFO original cmr shape(10, 128, 128)
# 2021-07-11 13:11:13,586 INFO (10, 128, 128, 2)
# 2021-07-11 13:11:13,588 INFO (10, 128, 128)
# 2021-07-11 13:11:13,588 INFO (10, 128, 128)
# 2021-07-11 13:11:13,589 INFO (10, 128, 128)
# 2021-07-11 13:11:13,590 INFO patient095
# 2021-07-11 13:11:13,591 INFO 28
# 2021-07-11 13:11:13,591 INFO length of ed_f 14
# 2021-07-11 13:11:13,591 INFO length of es_f 14
# 2021-07-11 13:11:13,592 INFO patient: patient095, phase: ED, files: 14
# 2021-07-11 13:11:13,592 INFO Create DataGenerator
# 2021-07-11 13:11:13,592 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:13,593 INFO No augmentation
# 2021-07-11 13:11:13,637 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 13:11:13,682 INFO original cmr shape(14, 128, 128)
# 2021-07-11 13:11:13,840 INFO (14, 128, 128, 2)
# 2021-07-11 13:11:13,842 INFO (14, 128, 128)
# 2021-07-11 13:11:13,843 INFO (14, 128, 128)
# 2021-07-11 13:11:13,843 INFO (14, 128, 128)
# 2021-07-11 13:11:13,845 INFO patient: patient095, phase: ES, files: 14
# 2021-07-11 13:11:13,846 INFO Create DataGenerator
# 2021-07-11 13:11:13,846 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 13:11:13,847 INFO No augmentation
# 2021-07-11 13:11:13,892 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 13:11:13,938 INFO original cmr shape(14, 128, 128)
# 2021-07-11 13:11:14,105 INFO (14, 128, 128, 2)
# 2021-07-11 13:11:14,107 INFO (14, 128, 128)
# 2021-07-11 13:11:14,107 INFO (14, 128, 128)
# 2021-07-11 13:11:14,107 INFO (14, 128, 128)
# 2021-07-11 13:11:14,110 INFO done! Check the /mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3folder for files

# %%
# Out:
# 2021-07-05 18:35:43,157 INFO patient098

# %% [markdown]
# ## code to figure out where we are currently

# %%
os.path.basename(x_val_sax[0]) #gives basename of the first file from x_val_sax
#os.path.split(x_val_sax[0])  # gives directory in which the x_val_sax files are located
# Out:
# 'patient007__t01_z0_img.nrrd'

# %% [raw]
# this gives us info on where the x_val_sax files are stored and what each file is named. But this is not necessarily the way these files sorted by the validation_generator I think? This would mean we need to find out the structure of that one.

# %%
#checks_out
export_path = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/'
ensure_dir(export_path)
_ = [sitk.WriteImage(img, '{}_{}'.format(export_path, os.path.basename(f_name))) for img, f_name in zip(gt_sitks, x_val_sax)]
# this might be important, need to figure out what it does exactly.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6155d990173a> in <module>
#       2 export_path = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/'
#       3 ensure_dir(export_path)
# ----> 4 _ = [sitk.WriteImage(img, '{}_{}'.format(export_path, os.path.basename(f_name))) for img, f_name in zip(gt_sitks, x_val_sax)]
#       5 # this might be important, need to figure out what it does exactly.
#
# NameError: name 'gt_sitks' is not defined

# %% [markdown]
# # Visualizations and Helper functions

# %%
#checks_out
#visualizes predictions
from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0,len(preds_flat)-1)):
    elem = gts_flat[elem]
    print(elem.shape)
    show_2D_or_3D(elem)
# Out:
# interactive(children=(IntSlider(value=237, description='elem', max=475), Output()), _dom_classes=('widget-inte…

# %%
#checks_out
from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0, len(x_val_sax))):
    temp = x_val_sax[elem]
    cmr = sitk.ReadImage(temp)
    cmr = sitk.GetArrayFromImage(cmr)
    temp = temp.replace('img', 'msk')
    temp = sitk.ReadImage(temp)
    temp = sitk.GetArrayFromImage(temp)
    #plt.imshow(temp, cmap='gray')
    
    show_2D_or_3D(cmr, temp)
# Out:
# interactive(children=(IntSlider(value=238, description='elem', max=476), Output()), _dom_classes=('widget-inte…

# %%
#checks_out

from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0,gts.shape[0])):
    temp = gts_cmr[elem]
    msk = gts_flat[elem]
    print(msk.shape)
    #plt.imshow(temp, cmap='gray')
    #plt.imshow(msk, alpha=0.8)
    show_2D_or_3D(temp, msk)
# Out:
# interactive(children=(IntSlider(value=238, description='elem', max=476), Output()), _dom_classes=('widget-inte…

# %%
#checks_out

generator = validation_generator
@interact
def select_image_in_batch(batch = (0,len(generator)-1, 1), im = (0,config['BATCHSIZE']- 1, 1), slice_n=(1,11), save=False, filepath='data/temp/', filename='temp_x.npy'):
    
    global x, y
    x, y = generator.__getitem__(batch)
    info('selected batch : ' + str(batch))
    # logging level == debug --> visualise the generator steps
    info('X shape: {}, Y shape: {}'.format(x.shape, y.shape))
    show_2D_or_3D(x[im], y[im], interpol='bilinear',dpi=100,f_size=(5,5))
    plt.show()
    
    plt.hist(x[im].flatten())
    plt.show()
    if save:
        ensure_dir(filepath)
        np.save(os.path.join(filepath, filename), x[im])
        logging.info('saved to {}'.format(os.path.join(filepath, filename)))
# Out:
# interactive(children=(IntSlider(value=237, description='batch', max=475), IntSlider(value=0, description='im',…

# %% [markdown]
# # Undo the generator steps
#
# - If we have masks, undo the cropping/padding, resampling etc. so that our masks have the same size/spacing and name as our input volumes
# - If we have regression coordinates, make sure that they could be applied on the input volumes

# %% [markdown]
# # Load the gts, predictions testwise

# %%
# # Some sample numpy data

# data = np.zeros((5,4,3,2))
# filename = 'testdata.nrrd'

# # Write to a NRRD file
# nrrd.write(filename, data)

# # Read the data back from file
# readdata, header = nrrd.read(filename)
# print(readdata.shape)
# print(header)

# %% [markdown]
# ## Converting numpy predictions into nrrd via pynrrd

# %%
# write 3d_nrrd file to disk
sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_cmr[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_temp_cmr.nrrd')

# %%
# write 3d_nrrd file to disk
sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_cmr[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_temp_cmr.nrrd')
